# %%
#script dropar tabela
import xmlrpc.client

#url      = "https://crm.brainess.com.br"
#db       = "sohome_18"
url  = "http://docker.gruposohome.com:8070/"  # NA MINHA VPS
db   = "odoo"   # NO LOCALHOST e no 8070
username = "tiago@sohome.com"
password = "admin"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid    = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")
print(f"✅ Conectado como uid={uid}")

# =====================================
# ALTERE AQUI
# =====================================
COD_PREVEN = 154  # código da tabela a dropar
EMP = 4          # empresa Focco (EMPR_ID) dona dessa tabela

# cod_preven pode se repetir em empresas diferentes — sem filtrar tambem por
# EMP este script apagaria as linhas/tabela de TODAS as empresas que
# compartilham o mesmo numero de cod_preven.
DOMAIN = [["cod_preven", "=", COD_PREVEN], ["empresa_focco", "=", EMP]]

# =====================================
# APAGA LINHAS DE PREÇO
# =====================================
ids = models.execute_kw(db, uid, password,
    "calculadora.price.line", "search",
    [DOMAIN]
)
print(f"Linhas encontradas: {len(ids)}")

if ids:
    models.execute_kw(db, uid, password, "calculadora.price.line", "unlink", [ids])
    print(f"✅ {len(ids)} linhas removidas (cod_preven={COD_PREVEN} empresa_focco={EMP})")
else:
    print("Nenhuma linha encontrada.")

# =====================================
# APAGA O REGISTRO DA TABELA
# =====================================
table_ids = models.execute_kw(db, uid, password,
    "calculadora.price.table", "search",
    [DOMAIN]
)
if table_ids:
    models.execute_kw(db, uid, password, "calculadora.price.table", "unlink", [table_ids])
    print(f"✅ Tabela cod_preven={COD_PREVEN} empresa_focco={EMP} removida de calculadora.price.table")
# Out:
# ✅ Conectado como uid=2
# Linhas encontradas: 2200
# ✅ 2200 linhas removidas (cod_preven=154 empresa_focco=4)
