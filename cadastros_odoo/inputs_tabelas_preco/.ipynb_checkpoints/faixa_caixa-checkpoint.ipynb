# %%
from sqlalchemy import create_engine
import pandas as pd
import xmlrpc.client


engine = create_engine(
    "postgresql+psycopg2://consulta:consulta@10.1.57.244:5432/dwfocco"
)
host = "10.1.57.244"
database = "dwfocco"
username = "consulta"
password = "consulta"

# %%
query = r"""
        WITH base AS (
            SELECT
                tp_it.ID AS PRECO_FOCCO_ID,
                it.COD_ITEM,
                tp.COD_PREVEN,
                tp.DESCRICAO AS TABELA_DESCRICAO,
                REGEXP_REPLACE(it.DESC_TECNICA, '^MODELO\s+', '', 'i') AS PRODUTO,
        
                car.COD_CAR,
                var.MNEMONICO,
                it_car.SEQ,
        
                tp_it.DES_FORMULA AS FORMULA,
                tp_it.PRECO AS PRECO,
                gci.DESCRICAO as DESCRICAO
        
            FROM TPRECOSVEN_IT tp_it
        
            JOIN TPRECOSVEN tp
                ON tp.ID = tp_it.TPRVEN_ID
        
            JOIN TITENS_COMERCIAL itcm
                ON itcm.ID = tp_it.ITCM_ID
        
            JOIN TITENS_EMPR it_emp
                ON it_emp.ID = itcm.ITEMPR_ID
        
            JOIN TITENS it
                ON it.ID = it_emp.ITEM_ID
        
            LEFT JOIN TPRC_REGRAS_COM reg_com
                ON reg_com.TPRVEN_IT_ID = tp_it.ID
        
            LEFT JOIN TCARACTERISTICAS car
                ON car.ID = reg_com.TCARAC_ID
        
            LEFT JOIN TITENS_CAR it_car
                ON it_car.ITEMPR_ID = it_emp.ID
               AND it_car.TCARAC_ID = reg_com.TCARAC_ID
        
            LEFT JOIN TPRC_REGRAS_VAR_COM reg_var
                ON reg_var.REGRA_COM_ID = reg_com.ID
        
            LEFT JOIN TVARIAVEIS var
                ON var.ID = reg_var.TVAR_ID
        
            LEFT JOIN TGRP_CLAS_ITE gci
                ON gci.ID = itcm.grp_clas_id
        
            WHERE tp_it.SIT = 1
              --AND it.COD_ITEM = '20001'
              AND tp.COD_PREVEN = 155
        )
        
        SELECT
            PRECO_FOCCO_ID,
            COD_ITEM,
            COD_PREVEN,
            TABELA_DESCRICAO,
            PRODUTO,
            DESCRICAO,
        
            MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'MODULACAO')      AS MODULACAO,
            MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'COMP_MODULO')    AS COMP_MODULO,
            MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'PROF_PRODUTO')   AS PROF_PRODUTO,
        
            REPLACE(
                MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'FX_TEC'),
                'FX ',
                ''
            ) AS FAIXA,
        
            MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'TIPO_ACAB')      AS TIPO_ACAB,
            MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'EMBAL_REFORCADA') AS EMBALAGEM,
        
            STRING_AGG(
                MNEMONICO,
                CHR(35)
                ORDER BY SEQ
            ) FILTER (WHERE MNEMONICO IS NOT NULL) AS CONFIGURACAO,
        
            FORMULA,
        
            STRING_AGG(
                COD_CAR || ':' || MNEMONICO,
                CHR(124)
                ORDER BY SEQ
            ) FILTER (
                WHERE COD_CAR IS NOT NULL
                  AND MNEMONICO IS NOT NULL
            ) AS RESP,
        
            PRECO
        
        FROM base
        
        GROUP BY
            PRECO_FOCCO_ID,
            COD_ITEM,
            COD_PREVEN,
            TABELA_DESCRICAO,
            PRODUTO,
            DESCRICAO,
            FORMULA,
            PRECO
        
        ORDER BY
            COD_ITEM,
            PRODUTO,
            MODULACAO,
            COMP_MODULO,
            PROF_PRODUTO,
            FAIXA,
            TIPO_ACAB,
            EMBALAGEM;
        """

# %%
df = pd.read_sql(query, engine)

engine.dispose()

# %%
df
# Out:
#         preco_focco_id cod_item  cod_preven       tabela_descricao  \
# 0             12313160    10000         155  TABELA CENTURY 2026.2
# 1             12313154    10000         155  TABELA CENTURY 2026.2
# 2             12313155    10000         155  TABELA CENTURY 2026.2
# 3             12313156    10000         155  TABELA CENTURY 2026.2
# 4             12313161    10000         155  TABELA CENTURY 2026.2
# ...                ...      ...         ...                    ...
# 252054        12312852     6523         155  TABELA CENTURY 2026.2
# 252055        12312801     6523         155  TABELA CENTURY 2026.2
# 252056        12312851     6523         155  TABELA CENTURY 2026.2
# 252057        12312850     6523         155  TABELA CENTURY 2026.2
# 252058        12312849     6523         155  TABELA CENTURY 2026.2
#
#                produto   descricao modulacao comp_modulo prof_produto faixa  \
# 0           ACABAMENTO  ACABAMENTO       NaN         NaN          NaN     B
# 1           ACABAMENTO  ACABAMENTO       NaN         NaN          NaN     C
# 2           ACABAMENTO  ACABAMENTO       NaN         NaN          NaN     D
# 3           ACABAMENTO  ACABAMENTO       NaN         NaN          NaN     E
# 4           ACABAMENTO  ACABAMENTO       NaN         NaN          NaN     F
# ...                ...         ...       ...         ...          ...   ...
# 252054  KIT MOTORIZADO         KIT       NaN         NaN          NaN   NaN
# 252055  KIT MOTORIZADO         KIT       NaN         NaN          NaN   NaN
# 252056  KIT MOTORIZADO         KIT       NaN         NaN          NaN   NaN
# 252057  KIT MOTORIZADO         KIT       NaN         NaN          NaN   NaN
# 252058  KIT MOTORIZADO         KIT       NaN         NaN          NaN   NaN
#
#        tipo_acab embalagem                        configuracao formula  \
# 0            NaN       NaN                                FX B     NaN
# 1            NaN       NaN                                FX C     NaN
# 2            NaN       NaN                                FX D     NaN
# 3            NaN       NaN                                FX E     NaN
# 4            NaN       NaN                                FX F     NaN
# ...          ...       ...                                 ...     ...
# 252054       NaN       NaN   TOUCH SMART#1 AS#ABERTURA DE 40CM     NaN
# 252055       NaN       NaN      SOFT TOUCH SMART ITALIANO#4 AS     NaN
# 252056       NaN       NaN   TOUCH SMART#1 AS#ABERTURA DE 35CM     NaN
# 252057       NaN       NaN  TOUCH SMART#1 AS#ABERTURA DE 156CM     NaN
# 252058       NaN       NaN           TOUCH SMART ITALIANO#4 AS     NaN
#
#                                                      resp     preco
# 0                                             FX_TEC:FX B   186.300
# 1                                             FX_TEC:FX C   221.490
# 2                                             FX_TEC:FX D   261.855
# 3                                             FX_TEC:FX E   308.430
# 4                                             FX_TEC:FX F   377.775
# ...                                                   ...       ...
# 252054  TIPO_KIT_MOT:TOUCH SMART|QTD_AS:1 AS|TAMANHO_A...  2240.000
# 252055  TIPO_KIT_MOT:SOFT TOUCH SMART ITALIANO|QTD_AS:...  6094.000
# 252056  TIPO_KIT_MOT:TOUCH SMART|QTD_AS:1 AS|TAMANHO_A...  2092.000
# 252057  TIPO_KIT_MOT:TOUCH SMART|QTD_AS:1 AS|TAMANHO_A...  3809.000
# 252058      TIPO_KIT_MOT:TOUCH SMART ITALIANO|QTD_AS:4 AS  5363.000
#
# [252059 rows x 16 columns]

# %%
df_caixa = df[
    df["produto"].str.contains("BLUMEN", case=False, na=False)
]

df_caixa[["cod_item", "produto", "faixa", "configuracao", "resp", "preco"]].to_excel("teste.xlsx", index=False)
# Out:
#        cod_item       produto      faixa  \
# 198255    22335        BLUMEN          B
# 198256    22335        BLUMEN          B
# 198257    22335        BLUMEN          C
# 198258    22335        BLUMEN          C
# 198259    22335        BLUMEN      COURO
# ...         ...           ...        ...
# 198316    22336  BLUMEN CAIXA  FORNECIDO
# 198317    22336  BLUMEN CAIXA          G
# 198318    22336  BLUMEN CAIXA          H
# 198319    22336  BLUMEN CAIXA          I
# 198320    22336  BLUMEN CAIXA          J
#
#                                              configuracao  \
# 198255  POL#0.84M#0.80M#0.77M#FX B#BASE GIRATORIA#CAIX...
# 198256  POL#0.84M#0.80M#0.77M#FX B#BASE GIRATORIA#SEM ...
# 198257  POL#0.84M#0.80M#0.77M#FX C#BASE GIRATORIA#CAIX...
# 198258  POL#0.84M#0.80M#0.77M#FX C#BASE GIRATORIA#SEM ...
# 198259  POL#0.84M#0.80M#0.77M#FX COURO#BASE GIRATORIA#...
# ...                                                   ...
# 198316                      PUFF#0.60M#0.52M#FX FORNECIDO
# 198317                              PUFF#0.60M#0.52M#FX G
# 198318                              PUFF#0.60M#0.52M#FX H
# 198319                              PUFF#0.60M#0.52M#FX I
# 198320                              PUFF#0.60M#0.52M#FX J
#
#                                                      resp   preco
# 198255  MODULACAO:POL|COMP_MODULO:0.84M|PROF_PRODUTO:0...  3265.0
# 198256  MODULACAO:POL|COMP_MODULO:0.84M|PROF_PRODUTO:0...  3165.0
# 198257  MODULACAO:POL|COMP_MODULO:0.84M|PROF_PRODUTO:0...  3374.0
# 198258  MODULACAO:POL|COMP_MODULO:0.84M|PROF_PRODUTO:0...  3274.0
# 198259  MODULACAO:POL|COMP_MODULO:0.84M|PROF_PRODUTO:0...  4223.0
# ...                                                   ...     ...
# 198316  MODULACAO:PUFF|COMP_MODULO:0.60M|PROF_PRODUTO:...    55.0
# 198317  MODULACAO:PUFF|COMP_MODULO:0.60M|PROF_PRODUTO:...   172.0
# 198318  MODULACAO:PUFF|COMP_MODULO:0.60M|PROF_PRODUTO:...   218.0
# 198319  MODULACAO:PUFF|COMP_MODULO:0.60M|PROF_PRODUTO:...   273.0
# 198320  MODULACAO:PUFF|COMP_MODULO:0.60M|PROF_PRODUTO:...   578.0
#
# [66 rows x 6 columns]
