# %%
from sqlalchemy import create_engine
import pandas as pd
import xmlrpc.client


engine = create_engine(
    "postgresql+psycopg2://consulta:consulta@10.1.57.244:5432/dwfocco"
)
host = "10.1.57.244"
database = "dwfocco"
username = "consulta"
password = "consulta"

# %%
query = r"""
        WITH base AS (
            SELECT
                TPRECOSVEN_IT.ID AS PRECO_FOCCO_ID,
                TITENS.COD_ITEM,
                TPRECOSVEN.COD_PREVEN,
                TPRECOSVEN.DESCRICAO AS TABELA_DESCRICAO,
                REGEXP_REPLACE(TITENS.DESC_TECNICA, '^MODELO\s+', '', 'i') AS PRODUTO,
        
                TCARACTERISTICAS.COD_CAR,
                TVARIAVEIS.MNEMONICO,
                TITENS_CAR.SEQ,
        
                TPRECOSVEN_IT.DES_FORMULA AS FORMULA,
                TPRECOSVEN_IT.PRECO AS PRECO
        
            FROM TPRECOSVEN_IT
        
            JOIN TPRECOSVEN
                ON TPRECOSVEN.ID = TPRECOSVEN_IT.TPRVEN_ID
        
            JOIN TITENS_COMERCIAL
                ON TITENS_COMERCIAL.ID = TPRECOSVEN_IT.ITCM_ID
        
            JOIN TITENS_EMPR
                ON TITENS_EMPR.ID = TITENS_COMERCIAL.ITEMPR_ID
        
            JOIN TITENS
                ON TITENS.ID = TITENS_EMPR.ITEM_ID
        
            LEFT JOIN TPRC_REGRAS_COM
                ON TPRC_REGRAS_COM.TPRVEN_IT_ID = TPRECOSVEN_IT.ID
        
            LEFT JOIN TCARACTERISTICAS
                ON TCARACTERISTICAS.ID = TPRC_REGRAS_COM.TCARAC_ID
        
            LEFT JOIN TITENS_CAR
                ON TITENS_CAR.ITEMPR_ID = TITENS_EMPR.ID
               AND TITENS_CAR.TCARAC_ID = TPRC_REGRAS_COM.TCARAC_ID
        
            LEFT JOIN TPRC_REGRAS_VAR_COM
                ON TPRC_REGRAS_VAR_COM.REGRA_COM_ID = TPRC_REGRAS_COM.ID
        
            LEFT JOIN TVARIAVEIS
                ON TVARIAVEIS.ID = TPRC_REGRAS_VAR_COM.TVAR_ID
        
            WHERE TPRECOSVEN_IT.SIT = 1
              --AND TITENS.COD_ITEM = '20001'
              AND TPRECOSVEN.COD_PREVEN = 255
        )
        
        SELECT
            PRECO_FOCCO_ID,
            COD_ITEM,
            COD_PREVEN,
            TABELA_DESCRICAO,
            PRODUTO,
        
            MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'MODULACAO') AS MODULACAO,
            MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'COMP_MODULO') AS COMP_MODULO,
            MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'PROF_PRODUTO') AS PROF_PRODUTO,
        
            REPLACE(
                MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'FX_TEC'),
                'FX ',
                ''
            ) AS FAIXA,
        
            MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'TIPO_ACAB') AS TIPO_ACAB,
            MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'EMBAL_REFORCADA') AS EMBALAGEM,
        
            STRING_AGG(
                MNEMONICO,
                CHR(35)
                ORDER BY SEQ
            ) FILTER (WHERE MNEMONICO IS NOT NULL) AS CONFIGURACAO,
        
            FORMULA,
        
            STRING_AGG(
                COD_CAR || ':' || MNEMONICO,
                CHR(124)
                ORDER BY SEQ
            ) FILTER (
                WHERE COD_CAR IS NOT NULL
                  AND MNEMONICO IS NOT NULL
            ) AS RESP,
        
            PRECO
        
        FROM base
        
        GROUP BY
            PRECO_FOCCO_ID,
            COD_ITEM,
            COD_PREVEN,
            TABELA_DESCRICAO,
            PRODUTO,
            FORMULA,
            PRECO
        
        ORDER BY
            COD_ITEM,
            PRODUTO,
            MODULACAO,
            COMP_MODULO,
            PROF_PRODUTO,
            FAIXA,
            TIPO_ACAB,
            EMBALAGEM;

        """

# %%
df = pd.read_sql(query, engine)

engine.dispose()

# %%
df
# Out:
#         preco_focco_id cod_item  cod_preven             tabela_descricao  \
# 0             11588742    20001         255  TABELA CENTURY DOLAR 2026.2
# 1             11588746    20001         255  TABELA CENTURY DOLAR 2026.2
# 2             11588749    20001         255  TABELA CENTURY DOLAR 2026.2
# 3             11588754    20001         255  TABELA CENTURY DOLAR 2026.2
# 4             11588758    20001         255  TABELA CENTURY DOLAR 2026.2
# ...                ...      ...         ...                          ...
# 246152        12309454     6523         255  TABELA CENTURY DOLAR 2026.2
# 246153        12309453     6523         255  TABELA CENTURY DOLAR 2026.2
# 246154        12309452     6523         255  TABELA CENTURY DOLAR 2026.2
# 246155        12309351     6523         255  TABELA CENTURY DOLAR 2026.2
# 246156        12309450     6523         255  TABELA CENTURY DOLAR 2026.2
#
#                produto     modulacao    comp_modulo prof_produto faixa  \
# 0                ADANA  1B + PUFF BI  1.00M + 0.80M        0.97M     B
# 1                ADANA  1B + PUFF BI  1.00M + 0.80M        0.97M     B
# 2                ADANA  1B + PUFF BI  1.00M + 0.80M        0.97M     B
# 3                ADANA  1B + PUFF BI  1.00M + 0.80M        0.97M     B
# 4                ADANA  1B + PUFF BI  1.00M + 0.80M        0.97M     B
# ...                ...           ...            ...          ...   ...
# 246152  KIT MOTORIZADO           NaN            NaN          NaN   NaN
# 246153  KIT MOTORIZADO           NaN            NaN          NaN   NaN
# 246154  KIT MOTORIZADO           NaN            NaN          NaN   NaN
# 246155  KIT MOTORIZADO           NaN            NaN          NaN   NaN
# 246156  KIT MOTORIZADO           NaN            NaN          NaN   NaN
#
#                  tipo_acab       embalagem  \
# 0            PINTURA FOSCA   CAIXA MADEIRA
# 1            PINTURA FOSCA  SEM CX MADEIRA
# 2       PINTURA METALIZADO   CAIXA MADEIRA
# 3       PINTURA METALIZADO  SEM CX MADEIRA
# 4              PINTURA MTX   CAIXA MADEIRA
# ...                    ...             ...
# 246152                 NaN             NaN
# 246153                 NaN             NaN
# 246154                 NaN             NaN
# 246155                 NaN             NaN
# 246156                 NaN             NaN
#
#                                              configuracao formula  \
# 0       1B + PUFF BI#1.00M + 0.80M#0.97M#FX B#PINTURA ...     NaN
# 1       1B + PUFF BI#1.00M + 0.80M#0.97M#FX B#PINTURA ...     NaN
# 2       1B + PUFF BI#1.00M + 0.80M#0.97M#FX B#PINTURA ...     NaN
# 3       1B + PUFF BI#1.00M + 0.80M#0.97M#FX B#PINTURA ...     NaN
# 4       1B + PUFF BI#1.00M + 0.80M#0.97M#FX B#PINTURA ...     NaN
# ...                                                   ...     ...
# 246152                    TOUCH#3 AS#ABERTURA DE 40CM CAM     NaN
# 246153                        TOUCH#3 AS#ABERTURA DE 40CM     NaN
# 246154                        TOUCH#3 AS#ABERTURA DE 35CM     NaN
# 246155             SOFT TOUCH SMART#1 AS#ABERTURA DE 35CM     NaN
# 246156                       TOUCH#3 AS#ABERTURA DE 156CM     NaN
#
#                                                      resp   preco
# 0       MODULACAO:1B + PUFF BI|COMP_MODULO:1.00M + 0.8...   949.0
# 1       MODULACAO:1B + PUFF BI|COMP_MODULO:1.00M + 0.8...   907.0
# 2       MODULACAO:1B + PUFF BI|COMP_MODULO:1.00M + 0.8...   949.0
# 3       MODULACAO:1B + PUFF BI|COMP_MODULO:1.00M + 0.8...   907.0
# 4       MODULACAO:1B + PUFF BI|COMP_MODULO:1.00M + 0.8...   823.0
# ...                                                   ...     ...
# 246152  TIPO_KIT_MOT:TOUCH|QTD_AS:3 AS|TAMANHO_ARTICUL...   536.0
# 246153  TIPO_KIT_MOT:TOUCH|QTD_AS:3 AS|TAMANHO_ARTICUL...   673.0
# 246154  TIPO_KIT_MOT:TOUCH|QTD_AS:3 AS|TAMANHO_ARTICUL...   625.0
# 246155  TIPO_KIT_MOT:SOFT TOUCH SMART|QTD_AS:1 AS|TAMA...   390.0
# 246156  TIPO_KIT_MOT:TOUCH|QTD_AS:3 AS|TAMANHO_ARTICUL...  1486.0
#
# [246157 rows x 15 columns]

# %%
df.to_pickle("df_precos.pkl")

# %%
import pandas as pd
df = pd.read_pickle("df_precos.pkl")

# %%
df_import = df.copy()

# %%
import xmlrpc.client
import pandas as pd

# =====================================
# ODOO
# =====================================
url = "https://crm.brainess.com.br"
db = "sohome_18"
username = "tiago@sohome.com"
password = "admin"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
if not uid:
    raise Exception("Falha na autenticação")

models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")
MODEL = "calculadora.price.line"

# =====================================
# MARCA DA TABELA — altere aqui antes de importar
# =====================================
MARCA = "PONTOVIRGULA"

# =====================================
# DATAFRAME
# =====================================
df_import = df.copy()
df_import.columns = [str(c).strip().upper() for c in df_import.columns]

required_cols = [
    "PRECO_FOCCO_ID", "COD_ITEM", "COD_PREVEN", "TABELA_DESCRICAO", "PRODUTO",
    "MODULACAO", "COMP_MODULO", "PROF_PRODUTO", "FAIXA", "TIPO_ACAB", "EMBALAGEM",
    "CONFIGURACAO", "FORMULA", "RESP", "PRECO",
]
missing = [c for c in required_cols if c not in df_import.columns]
if missing:
    raise Exception(f"Colunas ausentes no dataframe: {missing}")

print(f"Total de linhas no dataframe: {len(df_import)}")

# =====================================
# DIAGNÓSTICO MESA REINO (ou qualquer produto suspeito)
# =====================================
for produto_alvo in ["MESA REINO"]:
    mask = df_import["PRODUTO"].str.strip().str.upper() == produto_alvo.upper()
    encontradas = df_import[mask]
    print(f"\n[DIAGNÓSTICO] '{produto_alvo}': {len(encontradas)} linhas no dataframe")
    if not encontradas.empty:
        print(encontradas[["PRECO_FOCCO_ID", "PRODUTO", "FAIXA", "PRECO"]].to_string())

# =====================================
# FUNÇÕES DE LIMPEZA
# =====================================
def clean_str(value):
    if pd.isna(value):
        return ""
    return str(value).strip()

def clean_int(value):
    if pd.isna(value) or str(value).strip() == "":
        return None          # None em vez de 0 — distingue "sem ID" de "ID zero"
    try:
        return int(float(value))
    except (ValueError, TypeError):
        return None

def clean_float(value):
    if pd.isna(value) or str(value).strip() == "":
        return 0.0
    return float(value)

def row_to_vals(row):
    faixa_raw = clean_str(row["FAIXA"])
    faixa = faixa_raw.replace("FX ", "").strip()
    marca = clean_str(row.get("MARCA", "")) or MARCA
    return {
        "active": True,
        "preco_focco_id": clean_int(row["PRECO_FOCCO_ID"]),
        "cod_item": clean_str(row["COD_ITEM"]),
        "cod_preven": clean_int(row["COD_PREVEN"]) or 0,
        "tabela_descricao": clean_str(row["TABELA_DESCRICAO"]),
        "produto": clean_str(row["PRODUTO"]),
        "marca": marca,
        "modulacao": clean_str(row["MODULACAO"]),
        "comp_modulo": clean_str(row["COMP_MODULO"]),
        "prof_produto": clean_str(row["PROF_PRODUTO"]),
        "faixa": faixa,
        "faixa_raw": faixa_raw,          # só para log, não vai ao Odoo
        "tipo_acab": clean_str(row["TIPO_ACAB"]),
        "embalagem": clean_str(row["EMBALAGEM"]),
        "configuracao": clean_str(row["CONFIGURACAO"]),
        "formula": clean_str(row["FORMULA"]),
        "resp": clean_str(row["RESP"]),
        "preco": clean_float(row["PRECO"]),
    }

# =====================================
# BUSCA IDs JÁ CADASTRADOS (1 chamada só)
# =====================================
print("\nBuscando registros já cadastrados no Odoo...")
existing_records = models.execute_kw(
    db, uid, password,
    MODEL, "search_read",
    [[["preco_focco_id", "!=", False]]],
    {"fields": ["preco_focco_id"]}
)
existing_ids = {r["preco_focco_id"] for r in existing_records}
print(f"Registros já cadastrados: {len(existing_ids)}")

# =====================================
# FILTRA NOVOS REGISTROS — com log de motivo
# =====================================
rows_to_insert = []
skipped_sem_id      = []   # preco_focco_id ausente/nulo
skipped_sem_produto = []   # produto vazio
skipped_sem_faixa   = []   # faixa virou vazia após strip
skipped_duplicados  = 0    # já existe no Odoo (normal)

for idx, row in df_import.iterrows():
    vals = row_to_vals(row)
    produto  = vals["produto"]
    focco_id = vals["preco_focco_id"]
    faixa    = vals["faixa"]
    faixa_raw = vals.pop("faixa_raw")   # remove campo auxiliar antes de enviar

    if focco_id is None:
        skipped_sem_id.append({"idx": idx, "produto": produto, "faixa_raw": faixa_raw})
        continue

    if not produto:
        skipped_sem_produto.append({"idx": idx, "preco_focco_id": focco_id, "faixa_raw": faixa_raw})
        continue

    if not faixa:
        skipped_sem_faixa.append({"idx": idx, "produto": produto, "preco_focco_id": focco_id, "faixa_raw": faixa_raw})
        continue

    if focco_id in existing_ids:
        skipped_duplicados += 1
        continue

    rows_to_insert.append(vals)

# ── resumo dos ignorados ──────────────────────────────────────────────────────
print(f"\n{'='*50}")
print(f"Sem preco_focco_id : {len(skipped_sem_id):>6}")
print(f"Sem produto        : {len(skipped_sem_produto):>6}")
print(f"Faixa virou vazia  : {len(skipped_sem_faixa):>6}")
print(f"Já no Odoo (normal): {skipped_duplicados:>6}")
print(f"A inserir          : {len(rows_to_insert):>6}")
print(f"{'='*50}")

if skipped_sem_id:
    print("\n⚠️  Linhas sem preco_focco_id (podem ser válidas — verificar fonte):")
    print(pd.DataFrame(skipped_sem_id).head(20).to_string())

if skipped_sem_faixa:
    print("\n⚠️  Linhas com faixa vazia após strip:")
    print(pd.DataFrame(skipped_sem_faixa).head(20).to_string())

# =====================================
# IMPORTAÇÃO EM LOTES
# =====================================
BATCH_SIZE = 100
created = 0
errors  = []

try:
    for i in range(0, len(rows_to_insert), BATCH_SIZE):
        batch = rows_to_insert[i : i + BATCH_SIZE]
        try:
            models.execute_kw(db, uid, password, MODEL, "create", [batch])
            created += len(batch)
            print(f"  {created}/{len(rows_to_insert)} inseridos...")
        except Exception:
            for vals in batch:
                try:
                    models.execute_kw(db, uid, password, MODEL, "create", [vals])
                    created += 1
                except Exception as e2:
                    errors.append({
                        "preco_focco_id": vals.get("preco_focco_id"),
                        "produto": vals.get("produto"),
                        "erro": str(e2),
                    })

except KeyboardInterrupt:
    print("\nInterrompido — último lote pode ter sido inserido parcialmente")

finally:
    print(f"\n{'='*50}")
    print(f"Criados : {created}")
    print(f"Erros   : {len(errors)}")
    if errors:
        print(pd.DataFrame(errors).head(20).to_string())
# Out:
# Buscando registros já cadastrados no Odoo...
# Registros já cadastrados: 234159
# Registros a inserir: 228340
#   100/228340 inseridos...
#   200/228340 inseridos...
#   300/228340 inseridos...
#   400/228340 inseridos...
#   500/228340 inseridos...
#   600/228340 inseridos...
#   700/228340 inseridos...
#   800/228340 inseridos...
#   900/228340 inseridos...
#   1000/228340 inseridos...
#   1100/228340 inseridos...
#   1200/228340 inseridos...
#   1300/228340 inseridos...
#   1400/228340 inseridos...
#   1500/228340 inseridos...
#   1600/228340 inseridos...
#   1700/228340 inseridos...
#   1800/228340 inseridos...
#   1900/228340 inseridos...
#   2000/228340 inseridos...
#   2100/228340 inseridos...
#   2200/228340 inseridos...
#   2300/228340 inseridos...
#   2400/228340 inseridos...
#   2500/228340 inseridos...
#   2600/228340 inseridos...
#   2700/228340 inseridos...
#   2800/228340 inseridos...
#   2900/228340 inseridos...
#   3000/228340 inseridos...
#   3100/228340 inseridos...
#   3200/228340 inseridos...
#   3300/228340 inseridos...
#   3400/228340 inseridos...
#   3500/228340 inseridos...
#   3600/228340 inseridos...
#   3700/228340 inseridos...
#   3800/228340 inseridos...
#   3900/228340 inseridos...
#   4000/228340 inseridos...
#   4100/228340 inseridos...
#   4200/228340 inseridos...
#   4300/228340 inseridos...
#   4400/228340 inseridos...
#   4500/228340 inseridos...
#   4600/228340 inseridos...
#   4700/228340 inseridos...
#   4800/228340 inseridos...
#   4900/228340 inseridos...
#   5000/228340 inseridos...
#   5100/228340 inseridos...
#   5200/228340 inseridos...
#   5300/228340 inseridos...
#   5400/228340 inseridos...
#   5500/228340 inseridos...
#   5600/228340 inseridos...
#   5700/228340 inseridos...
#   5800/228340 inseridos...
#   5900/228340 inseridos...
#   6000/228340 inseridos...
#   6100/228340 inseridos...
#   6200/228340 inseridos...
#   6300/228340 inseridos...
#   6400/228340 inseridos...
#   6500/228340 inseridos...
#   6600/228340 inseridos...
#   6700/228340 inseridos...
#   6800/228340 inseridos...
#   6900/228340 inseridos...
#   7000/228340 inseridos...
#   7100/228340 inseridos...
#   7200/228340 inseridos...
#   7300/228340 inseridos...
#   7400/228340 inseridos...
#   7500/228340 inseridos...
#   7600/228340 inseridos...
#   7700/228340 inseridos...
#   7800/228340 inseridos...
#   7900/228340 inseridos...
#   8000/228340 inseridos...
#   8100/228340 inseridos...
#   8200/228340 inseridos...
#   8300/228340 inseridos...
#   8400/228340 inseridos...
#   8500/228340 inseridos...
#   8600/228340 inseridos...
#   8700/228340 inseridos...
#   8800/228340 inseridos...
#   8900/228340 inseridos...
#   9000/228340 inseridos...
#   9100/228340 inseridos...
#   9200/228340 inseridos...
#   9300/228340 inseridos...
#   9400/228340 inseridos...
#   9500/228340 inseridos...
#   9600/228340 inseridos...
#   9700/228340 inseridos...
#   9800/228340 inseridos...
#   9900/228340 inseridos...
#   10000/228340 inseridos...
#   10100/228340 inseridos...
#   10200/228340 inseridos...
#   10300/228340 inseridos...
#   10400/228340 inseridos...
#   10500/228340 inseridos...
#   10600/228340 inseridos...
#   10700/228340 inseridos...
#   10800/228340 inseridos...
#   10900/228340 inseridos...
#   11000/228340 inseridos...
#   11100/228340 inseridos...
#   11200/228340 inseridos...
#   11300/228340 inseridos...
#   11400/228340 inseridos...
#   11500/228340 inseridos...
#   11600/228340 inseridos...
#   11700/228340 inseridos...
#   11800/228340 inseridos...
#   11900/228340 inseridos...
#   12000/228340 inseridos...
#   12100/228340 inseridos...
#   12200/228340 inseridos...
#   12300/228340 inseridos...
#   12400/228340 inseridos...
#   12500/228340 inseridos...
#   12600/228340 inseridos...
#   12700/228340 inseridos...
#   12800/228340 inseridos...
#   12900/228340 inseridos...
#   13000/228340 inseridos...
#   13100/228340 inseridos...
#   13200/228340 inseridos...
#   13300/228340 inseridos...
#   13400/228340 inseridos...
#   13500/228340 inseridos...
#   13600/228340 inseridos...
#   13700/228340 inseridos...
#   13800/228340 inseridos...
#   13900/228340 inseridos...
#   14000/228340 inseridos...
#   14100/228340 inseridos...
#   14200/228340 inseridos...
#   14300/228340 inseridos...
#   14400/228340 inseridos...
#   14500/228340 inseridos...
#   14600/228340 inseridos...
#   14700/228340 inseridos...
#   14800/228340 inseridos...
#   14900/228340 inseridos...
#   15000/228340 inseridos...
#   15100/228340 inseridos...
#   15200/228340 inseridos...
#   15300/228340 inseridos...
#   15400/228340 inseridos...
#   15500/228340 inseridos...
#   15600/228340 inseridos...
#   15700/228340 inseridos...
#   15800/228340 inseridos...
#   15900/228340 inseridos...
#   16000/228340 inseridos...
#   16100/228340 inseridos...
#   16200/228340 inseridos...
#   16300/228340 inseridos...
#   16400/228340 inseridos...
#   16500/228340 inseridos...
#   16600/228340 inseridos...
#   16700/228340 inseridos...
#   16800/228340 inseridos...
#   16900/228340 inseridos...
#   17000/228340 inseridos...
#   17100/228340 inseridos...
#   17200/228340 inseridos...
#   17300/228340 inseridos...
#   17400/228340 inseridos...
#   17500/228340 inseridos...
#   17600/228340 inseridos...
#   17700/228340 inseridos...
#   17800/228340 inseridos...
#   17900/228340 inseridos...
#   18000/228340 inseridos...
#   18100/228340 inseridos...
#   18200/228340 inseridos...
#   18300/228340 inseridos...
#   18400/228340 inseridos...
#   18500/228340 inseridos...
#   18600/228340 inseridos...
#   18700/228340 inseridos...
#   18800/228340 inseridos...
#   18900/228340 inseridos...
#   19000/228340 inseridos...
#   19100/228340 inseridos...
#   19200/228340 inseridos...
#   19300/228340 inseridos...
#   19400/228340 inseridos...
#   19500/228340 inseridos...
#   19600/228340 inseridos...
#   19700/228340 inseridos...
#   19800/228340 inseridos...
#   19900/228340 inseridos...
#   20000/228340 inseridos...
#   20100/228340 inseridos...
#   20200/228340 inseridos...
#   20300/228340 inseridos...
#   20400/228340 inseridos...
#   20500/228340 inseridos...
#   20600/228340 inseridos...
#   20700/228340 inseridos...
#   20800/228340 inseridos...
#   20900/228340 inseridos...
#   21000/228340 inseridos...
#   21100/228340 inseridos...
#   21200/228340 inseridos...
#   21300/228340 inseridos...
#   21400/228340 inseridos...
#   21500/228340 inseridos...
#   21600/228340 inseridos...
#   21700/228340 inseridos...
#   21800/228340 inseridos...
#   21900/228340 inseridos...
#   22000/228340 inseridos...
#   22100/228340 inseridos...
#   22200/228340 inseridos...
#   22300/228340 inseridos...
#   22400/228340 inseridos...
#   22500/228340 inseridos...
#   22600/228340 inseridos...
#   22700/228340 inseridos...
#   22800/228340 inseridos...
#   22900/228340 inseridos...
#   23000/228340 inseridos...
#   23100/228340 inseridos...
#   23200/228340 inseridos...
#   23300/228340 inseridos...
#   23400/228340 inseridos...
#   23500/228340 inseridos...
#   23600/228340 inseridos...
#   23700/228340 inseridos...
#   23800/228340 inseridos...
#   23900/228340 inseridos...
#   24000/228340 inseridos...
#   24100/228340 inseridos...
#   24200/228340 inseridos...
#   24300/228340 inseridos...
#   24400/228340 inseridos...
#   24500/228340 inseridos...
#   24600/228340 inseridos...
#   24700/228340 inseridos...
#   24800/228340 inseridos...
#   24900/228340 inseridos...
#   25000/228340 inseridos...
#   25100/228340 inseridos...
#   25200/228340 inseridos...
#   25300/228340 inseridos...
#   25400/228340 inseridos...
#   25500/228340 inseridos...
#   25600/228340 inseridos...
#   25700/228340 inseridos...
#   25800/228340 inseridos...
#   25900/228340 inseridos...
#   26000/228340 inseridos...
#   26100/228340 inseridos...
#   26200/228340 inseridos...
#   26300/228340 inseridos...
#   26400/228340 inseridos...
#   26500/228340 inseridos...
#   26600/228340 inseridos...
#   26700/228340 inseridos...
#   26800/228340 inseridos...
#   26900/228340 inseridos...
#   27000/228340 inseridos...
#   27100/228340 inseridos...
#   27200/228340 inseridos...
#   27300/228340 inseridos...
#   27400/228340 inseridos...
#   27500/228340 inseridos...
#   27600/228340 inseridos...
#   27700/228340 inseridos...
#   27800/228340 inseridos...
#   27900/228340 inseridos...
#   28000/228340 inseridos...
#   28100/228340 inseridos...
#   28200/228340 inseridos...
#   28300/228340 inseridos...
#   28400/228340 inseridos...
#   28500/228340 inseridos...
#   28600/228340 inseridos...
#   28700/228340 inseridos...
#   28800/228340 inseridos...
#   28900/228340 inseridos...
#   29000/228340 inseridos...
#   29100/228340 inseridos...
#   29200/228340 inseridos...
#   29300/228340 inseridos...
#   29400/228340 inseridos...
#   29500/228340 inseridos...
#   29600/228340 inseridos...
#   29700/228340 inseridos...
#   29800/228340 inseridos...
#   29900/228340 inseridos...
#   30000/228340 inseridos...
#   30100/228340 inseridos...
#   30200/228340 inseridos...
#   30300/228340 inseridos...
#   30400/228340 inseridos...
#   30500/228340 inseridos...
#   30600/228340 inseridos...
#   30700/228340 inseridos...
#   30800/228340 inseridos...
#   30900/228340 inseridos...
#   31000/228340 inseridos...
#   31100/228340 inseridos...
#   31200/228340 inseridos...
#   31300/228340 inseridos...
#   31400/228340 inseridos...
#   31500/228340 inseridos...
#   31600/228340 inseridos...
#   31700/228340 inseridos...
#   31800/228340 inseridos...
#   31900/228340 inseridos...
#   32000/228340 inseridos...
#   32100/228340 inseridos...
#   32200/228340 inseridos...
#   32300/228340 inseridos...
#   32400/228340 inseridos...
#   32500/228340 inseridos...
#   32600/228340 inseridos...
#   32700/228340 inseridos...
#   32800/228340 inseridos...
#   32900/228340 inseridos...
#   33000/228340 inseridos...
#   33100/228340 inseridos...
#   33200/228340 inseridos...
#   33300/228340 inseridos...
#   33400/228340 inseridos...
#   33500/228340 inseridos...
#   33600/228340 inseridos...
#   33700/228340 inseridos...
#   33800/228340 inseridos...
#   33900/228340 inseridos...
#   34000/228340 inseridos...
#   34100/228340 inseridos...
#   34200/228340 inseridos...
#   34300/228340 inseridos...
#   34400/228340 inseridos...
#   34500/228340 inseridos...
#   34600/228340 inseridos...
#   34700/228340 inseridos...
#   34800/228340 inseridos...
#   34900/228340 inseridos...
#   35000/228340 inseridos...
#   35100/228340 inseridos...
#   35200/228340 inseridos...
#   35300/228340 inseridos...
#   35400/228340 inseridos...
#   35500/228340 inseridos...
#   35600/228340 inseridos...
#   35700/228340 inseridos...
#   35800/228340 inseridos...
#   35900/228340 inseridos...
#   36000/228340 inseridos...
#   36100/228340 inseridos...
#   36200/228340 inseridos...
#   36300/228340 inseridos...
#   36400/228340 inseridos...
#   36500/228340 inseridos...
#   36600/228340 inseridos...
#   36700/228340 inseridos...
#   36800/228340 inseridos...
#   36900/228340 inseridos...
#   37000/228340 inseridos...
#   37100/228340 inseridos...
#   37200/228340 inseridos...
#   37300/228340 inseridos...
#   37400/228340 inseridos...
#   37500/228340 inseridos...
#   37600/228340 inseridos...
#   37700/228340 inseridos...
#   37800/228340 inseridos...
#   37900/228340 inseridos...
#   38000/228340 inseridos...
#   38100/228340 inseridos...
#   38200/228340 inseridos...
#   38300/228340 inseridos...
#   38400/228340 inseridos...
#   38500/228340 inseridos...
#   38600/228340 inseridos...
#   38700/228340 inseridos...
#   38800/228340 inseridos...
#   38900/228340 inseridos...
#   39000/228340 inseridos...
#   39100/228340 inseridos...
#   39200/228340 inseridos...
#   39300/228340 inseridos...
#   39400/228340 inseridos...
#   39500/228340 inseridos...
#   39600/228340 inseridos...
#   39700/228340 inseridos...
#   39800/228340 inseridos...
#   39900/228340 inseridos...
#   40000/228340 inseridos...
#   40100/228340 inseridos...
#   40200/228340 inseridos...
#   40300/228340 inseridos...
#   40400/228340 inseridos...
#   40500/228340 inseridos...
#   40600/228340 inseridos...
#   40700/228340 inseridos...
#   40800/228340 inseridos...
#   40900/228340 inseridos...
#   41000/228340 inseridos...
#   41100/228340 inseridos...
#   41200/228340 inseridos...
#   41300/228340 inseridos...
#   41400/228340 inseridos...
#   41500/228340 inseridos...
#   41600/228340 inseridos...
#   41700/228340 inseridos...
#   41800/228340 inseridos...
#   41900/228340 inseridos...
#   42000/228340 inseridos...
#   42100/228340 inseridos...
#   42200/228340 inseridos...
#   42300/228340 inseridos...
#   42400/228340 inseridos...
#   42500/228340 inseridos...
#   42600/228340 inseridos...
#   42700/228340 inseridos...
#   42800/228340 inseridos...
#   42900/228340 inseridos...
#   43000/228340 inseridos...
#   43100/228340 inseridos...
#   43200/228340 inseridos...
#   43300/228340 inseridos...
#   43400/228340 inseridos...
#   43500/228340 inseridos...
#   43600/228340 inseridos...
#   43700/228340 inseridos...
#   43800/228340 inseridos...
#   43900/228340 inseridos...
#   44000/228340 inseridos...
#   44100/228340 inseridos...
#   44200/228340 inseridos...
#   44300/228340 inseridos...
#   44400/228340 inseridos...
#   44500/228340 inseridos...
#   44600/228340 inseridos...
#   44700/228340 inseridos...
#   44800/228340 inseridos...
#   44900/228340 inseridos...
#   45000/228340 inseridos...
#   45100/228340 inseridos...
#   45200/228340 inseridos...
#   45300/228340 inseridos...
#   45400/228340 inseridos...
#   45500/228340 inseridos...
#   45600/228340 inseridos...
#   45700/228340 inseridos...
#   45800/228340 inseridos...
#   45900/228340 inseridos...
#   46000/228340 inseridos...
#   46100/228340 inseridos...
#   46200/228340 inseridos...
#   46300/228340 inseridos...
#   46400/228340 inseridos...
#   46500/228340 inseridos...
#   46600/228340 inseridos...
#   46700/228340 inseridos...
#   46800/228340 inseridos...
#   46900/228340 inseridos...
#   47000/228340 inseridos...
#   47100/228340 inseridos...
#   47200/228340 inseridos...
#   47300/228340 inseridos...
#   47400/228340 inseridos...
#   47500/228340 inseridos...
#   47600/228340 inseridos...
#   47700/228340 inseridos...
#   47800/228340 inseridos...
#   47900/228340 inseridos...
#   48000/228340 inseridos...
#   48100/228340 inseridos...
#   48200/228340 inseridos...
#   48300/228340 inseridos...
#   48400/228340 inseridos...
#   48500/228340 inseridos...
#   48600/228340 inseridos...
#   48700/228340 inseridos...
#   48800/228340 inseridos...
#   48900/228340 inseridos...
#   49000/228340 inseridos...
#   49100/228340 inseridos...
#   49200/228340 inseridos...
#   49300/228340 inseridos...
#   49400/228340 inseridos...
#   49500/228340 inseridos...
#   49600/228340 inseridos...
#   49700/228340 inseridos...
#   49800/228340 inseridos...
#   49900/228340 inseridos...
#   50000/228340 inseridos...
#   50100/228340 inseridos...
#   50200/228340 inseridos...
#   50300/228340 inseridos...
#   50400/228340 inseridos...
#   50500/228340 inseridos...
#   50600/228340 inseridos...
#   50700/228340 inseridos...
#   50800/228340 inseridos...
#   50900/228340 inseridos...
#   51000/228340 inseridos...
#   51100/228340 inseridos...
#   51200/228340 inseridos...
#   51300/228340 inseridos...
#   51400/228340 inseridos...
#   51500/228340 inseridos...
#   51600/228340 inseridos...
#   51700/228340 inseridos...
#   51800/228340 inseridos...
#   51900/228340 inseridos...
#   52000/228340 inseridos...
#   52100/228340 inseridos...
#   52200/228340 inseridos...
#   52300/228340 inseridos...
#   52400/228340 inseridos...
#   52500/228340 inseridos...
#   52600/228340 inseridos...
#   52700/228340 inseridos...
#   52800/228340 inseridos...
#   52900/228340 inseridos...
#   53000/228340 inseridos...
#   53100/228340 inseridos...
#   53200/228340 inseridos...
#   53300/228340 inseridos...
#   53400/228340 inseridos...
#   53500/228340 inseridos...
#   53600/228340 inseridos...
#   53700/228340 inseridos...
#   53800/228340 inseridos...
#   53900/228340 inseridos...
#   54000/228340 inseridos...
#   54100/228340 inseridos...
#   54200/228340 inseridos...
#   54300/228340 inseridos...
#   54400/228340 inseridos...
#   54500/228340 inseridos...
#   54600/228340 inseridos...
#   54700/228340 inseridos...
#   54800/228340 inseridos...
#   54900/228340 inseridos...
#   55000/228340 inseridos...
#   55100/228340 inseridos...
#   55200/228340 inseridos...
#   55300/228340 inseridos...
#   55400/228340 inseridos...
#   55500/228340 inseridos...
#   55600/228340 inseridos...
#   55700/228340 inseridos...
#   55800/228340 inseridos...
#   55900/228340 inseridos...
#   56000/228340 inseridos...
#   56100/228340 inseridos...
#   56200/228340 inseridos...
#   56300/228340 inseridos...
#   56400/228340 inseridos...
#   56500/228340 inseridos...
#   56600/228340 inseridos...
#   56700/228340 inseridos...
#   56800/228340 inseridos...
#   56900/228340 inseridos...
#   57000/228340 inseridos...
#   57100/228340 inseridos...
#   57200/228340 inseridos...
#   57300/228340 inseridos...
#   57400/228340 inseridos...
#   57500/228340 inseridos...
#   57600/228340 inseridos...
#   57700/228340 inseridos...
#   57800/228340 inseridos...
#   57900/228340 inseridos...
#   58000/228340 inseridos...
#   58100/228340 inseridos...
#   58200/228340 inseridos...
#   58300/228340 inseridos...
#   58400/228340 inseridos...
#   58500/228340 inseridos...
#   58600/228340 inseridos...
#   58700/228340 inseridos...
#   58800/228340 inseridos...
#   58900/228340 inseridos...
#   59000/228340 inseridos...
#   59100/228340 inseridos...
#   59200/228340 inseridos...
#   59300/228340 inseridos...
#   59400/228340 inseridos...
#   59500/228340 inseridos...
#   59600/228340 inseridos...
#   59700/228340 inseridos...
#   59800/228340 inseridos...
#   59900/228340 inseridos...
#   60000/228340 inseridos...
#   60100/228340 inseridos...
#   60200/228340 inseridos...
#   60300/228340 inseridos...
#   60400/228340 inseridos...
#   60500/228340 inseridos...
#   60600/228340 inseridos...
#   60700/228340 inseridos...
#   60800/228340 inseridos...
#   60900/228340 inseridos...
#   61000/228340 inseridos...
#   61100/228340 inseridos...
#   61200/228340 inseridos...
#   61300/228340 inseridos...
#   61400/228340 inseridos...
#   61500/228340 inseridos...
#   61600/228340 inseridos...
#   61700/228340 inseridos...
#   61800/228340 inseridos...
#   61900/228340 inseridos...
#   62000/228340 inseridos...
#   62100/228340 inseridos...
#   62200/228340 inseridos...
#   62300/228340 inseridos...
#   62400/228340 inseridos...
#   62500/228340 inseridos...
#   62600/228340 inseridos...
#   62700/228340 inseridos...
#   62800/228340 inseridos...
#   62900/228340 inseridos...
#   63000/228340 inseridos...
#   63100/228340 inseridos...
#   63200/228340 inseridos...
#   63300/228340 inseridos...
#   63400/228340 inseridos...
#   63500/228340 inseridos...
#   63600/228340 inseridos...
#   63700/228340 inseridos...
#   63800/228340 inseridos...
#   63900/228340 inseridos...
#   64000/228340 inseridos...
#   64100/228340 inseridos...
#   64200/228340 inseridos...
#   64300/228340 inseridos...
#   64400/228340 inseridos...
#   64500/228340 inseridos...
#   64600/228340 inseridos...
#   64700/228340 inseridos...
#   64800/228340 inseridos...
#   64900/228340 inseridos...
#   65000/228340 inseridos...
#   65100/228340 inseridos...
#   65200/228340 inseridos...
#   65300/228340 inseridos...
#   65400/228340 inseridos...
#   65500/228340 inseridos...
#   65600/228340 inseridos...
#   65700/228340 inseridos...
#   65800/228340 inseridos...
#   65900/228340 inseridos...
#   66000/228340 inseridos...
#   66100/228340 inseridos...
#   66200/228340 inseridos...
#   66300/228340 inseridos...
#   66400/228340 inseridos...
#   66500/228340 inseridos...
#   66600/228340 inseridos...
#   66700/228340 inseridos...
#   66800/228340 inseridos...
#   66900/228340 inseridos...
#   67000/228340 inseridos...
#   67100/228340 inseridos...
#   67200/228340 inseridos...
#   67300/228340 inseridos...
#   67400/228340 inseridos...
#   67500/228340 inseridos...
#   67600/228340 inseridos...
#   67700/228340 inseridos...
#   67800/228340 inseridos...
#   67900/228340 inseridos...
#   68000/228340 inseridos...
#   68100/228340 inseridos...
#   68200/228340 inseridos...
#   68300/228340 inseridos...
#   68400/228340 inseridos...
#   68500/228340 inseridos...
#   68600/228340 inseridos...
#   68700/228340 inseridos...
#   68800/228340 inseridos...
#   68900/228340 inseridos...
#   69000/228340 inseridos...
#   69100/228340 inseridos...
#   69200/228340 inseridos...
#   69300/228340 inseridos...
#   69400/228340 inseridos...
#   69500/228340 inseridos...
#   69600/228340 inseridos...
#   69700/228340 inseridos...
#   69800/228340 inseridos...
#   69900/228340 inseridos...
#   70000/228340 inseridos...
#   70100/228340 inseridos...
#   70200/228340 inseridos...
#   70300/228340 inseridos...
#   70400/228340 inseridos...
#   70500/228340 inseridos...
#   70600/228340 inseridos...
#   70700/228340 inseridos...
#   70800/228340 inseridos...
#   70900/228340 inseridos...
#   71000/228340 inseridos...
#   71100/228340 inseridos...
#   71200/228340 inseridos...
#   71300/228340 inseridos...
#   71400/228340 inseridos...
#   71500/228340 inseridos...
#   71600/228340 inseridos...
#   71700/228340 inseridos...
#   71800/228340 inseridos...
#   71900/228340 inseridos...
#   72000/228340 inseridos...
#   72100/228340 inseridos...
#   72200/228340 inseridos...
#   72300/228340 inseridos...
#   72400/228340 inseridos...
#   72500/228340 inseridos...
#   72600/228340 inseridos...
#   72700/228340 inseridos...
#   72800/228340 inseridos...
#   72900/228340 inseridos...
#   73000/228340 inseridos...
#   73100/228340 inseridos...
#   73200/228340 inseridos...
#   73300/228340 inseridos...
#   73400/228340 inseridos...
#   73500/228340 inseridos...
#   73600/228340 inseridos...
#   73700/228340 inseridos...
#   73800/228340 inseridos...
#   73900/228340 inseridos...
#   74000/228340 inseridos...
#   74100/228340 inseridos...
#   74200/228340 inseridos...
#   74300/228340 inseridos...
#   74400/228340 inseridos...
#   74500/228340 inseridos...
#   74600/228340 inseridos...
#   74700/228340 inseridos...
#   74800/228340 inseridos...
#   74900/228340 inseridos...
#   75000/228340 inseridos...
#   75100/228340 inseridos...
#   75200/228340 inseridos...
#   75300/228340 inseridos...
#   75400/228340 inseridos...
#   75500/228340 inseridos...
#   75600/228340 inseridos...
#   75700/228340 inseridos...
#   75800/228340 inseridos...
#   75900/228340 inseridos...
#   76000/228340 inseridos...
#   76100/228340 inseridos...
#   76200/228340 inseridos...
#   76300/228340 inseridos...
#   76400/228340 inseridos...
#   76500/228340 inseridos...
#   76600/228340 inseridos...
#   76700/228340 inseridos...
#   76800/228340 inseridos...
#   76900/228340 inseridos...
#   77000/228340 inseridos...
#   77100/228340 inseridos...
#   77200/228340 inseridos...
#   77300/228340 inseridos...
#   77400/228340 inseridos...
#   77500/228340 inseridos...
#   77600/228340 inseridos...
#   77700/228340 inseridos...
#   77800/228340 inseridos...
#   77900/228340 inseridos...
#   78000/228340 inseridos...
#   78100/228340 inseridos...
#   78200/228340 inseridos...
#   78300/228340 inseridos...
#   78400/228340 inseridos...
#   78500/228340 inseridos...
#   78600/228340 inseridos...
#   78700/228340 inseridos...
#   78800/228340 inseridos...
#   78900/228340 inseridos...
#   79000/228340 inseridos...
#   79100/228340 inseridos...
#   79200/228340 inseridos...
#   79300/228340 inseridos...
#   79400/228340 inseridos...
#   79500/228340 inseridos...
#   79600/228340 inseridos...
#   79700/228340 inseridos...
#   79800/228340 inseridos...
#   79900/228340 inseridos...
#   80000/228340 inseridos...
#   80100/228340 inseridos...
#   80200/228340 inseridos...
#   80300/228340 inseridos...
#   80400/228340 inseridos...
#   80500/228340 inseridos...
#   80600/228340 inseridos...
#   80700/228340 inseridos...
#   80800/228340 inseridos...
#   80900/228340 inseridos...
#   81000/228340 inseridos...
#   81100/228340 inseridos...
#   81200/228340 inseridos...
#   81300/228340 inseridos...
#   81400/228340 inseridos...
#   81500/228340 inseridos...
#   81600/228340 inseridos...
#   81700/228340 inseridos...
#   81800/228340 inseridos...
#   81900/228340 inseridos...
#   82000/228340 inseridos...
#   82100/228340 inseridos...
#   82200/228340 inseridos...
#   82300/228340 inseridos...
#   82400/228340 inseridos...
#   82500/228340 inseridos...
#   82600/228340 inseridos...
#   82700/228340 inseridos...
#   82800/228340 inseridos...
#   82900/228340 inseridos...
#   83000/228340 inseridos...
#   83100/228340 inseridos...
#   83200/228340 inseridos...
#   83300/228340 inseridos...
#   83400/228340 inseridos...
#   83500/228340 inseridos...
#   83600/228340 inseridos...
#   83700/228340 inseridos...
#   83800/228340 inseridos...
#   83900/228340 inseridos...
#   84000/228340 inseridos...
#   84100/228340 inseridos...
#   84200/228340 inseridos...
#   84300/228340 inseridos...
#   84400/228340 inseridos...
#   84500/228340 inseridos...
#   84600/228340 inseridos...
#   84700/228340 inseridos...
#   84800/228340 inseridos...
#   84900/228340 inseridos...
#   85000/228340 inseridos...
#   85100/228340 inseridos...
#   85200/228340 inseridos...
#   85300/228340 inseridos...
#   85400/228340 inseridos...
#   85500/228340 inseridos...
#   85600/228340 inseridos...
#   85700/228340 inseridos...
#   85800/228340 inseridos...
#   85900/228340 inseridos...
#   86000/228340 inseridos...
#   86100/228340 inseridos...
#   86200/228340 inseridos...
#   86300/228340 inseridos...
#   86400/228340 inseridos...
#   86500/228340 inseridos...
#   86600/228340 inseridos...
#   86700/228340 inseridos...
#   86800/228340 inseridos...
#   86900/228340 inseridos...
#   87000/228340 inseridos...
#   87100/228340 inseridos...
#   87200/228340 inseridos...
#   87300/228340 inseridos...
#   87400/228340 inseridos...
#   87500/228340 inseridos...
#   87600/228340 inseridos...
#   87700/228340 inseridos...
#   87800/228340 inseridos...
#   87900/228340 inseridos...
#   88000/228340 inseridos...
#   88100/228340 inseridos...
#   88200/228340 inseridos...
#   88300/228340 inseridos...
#   88400/228340 inseridos...
#   88500/228340 inseridos...
#   88600/228340 inseridos...
#   88700/228340 inseridos...
#   88800/228340 inseridos...
#   88900/228340 inseridos...
#   89000/228340 inseridos...
#   89100/228340 inseridos...
#   89200/228340 inseridos...
#   89300/228340 inseridos...
#   89400/228340 inseridos...
#   89500/228340 inseridos...
#   89600/228340 inseridos...
#   89700/228340 inseridos...
#   89800/228340 inseridos...
#   89900/228340 inseridos...
#   90000/228340 inseridos...
#   90100/228340 inseridos...
#   90200/228340 inseridos...
#   90300/228340 inseridos...
#   90400/228340 inseridos...
#   90500/228340 inseridos...
#   90600/228340 inseridos...
#   90700/228340 inseridos...
#   90800/228340 inseridos...
#   90900/228340 inseridos...
#   91000/228340 inseridos...
#   91100/228340 inseridos...
#   91200/228340 inseridos...
#   91300/228340 inseridos...
#   91400/228340 inseridos...
#   91500/228340 inseridos...
#   91600/228340 inseridos...
#   91700/228340 inseridos...
#   91800/228340 inseridos...
#   91900/228340 inseridos...
#   92000/228340 inseridos...
#   92100/228340 inseridos...
#   92200/228340 inseridos...
#   92300/228340 inseridos...
#   92400/228340 inseridos...
#   92500/228340 inseridos...
#   92600/228340 inseridos...
#   92700/228340 inseridos...
#   92800/228340 inseridos...
#   92900/228340 inseridos...
#   93000/228340 inseridos...
#   93100/228340 inseridos...
#   93200/228340 inseridos...
#   93300/228340 inseridos...
#   93400/228340 inseridos...
#   93500/228340 inseridos...
#   93600/228340 inseridos...
#   93700/228340 inseridos...
#   93800/228340 inseridos...
#   93900/228340 inseridos...
#   94000/228340 inseridos...
#   94100/228340 inseridos...
#   94200/228340 inseridos...
#   94300/228340 inseridos...
#   94400/228340 inseridos...
#   94500/228340 inseridos...
#   94600/228340 inseridos...
#   94700/228340 inseridos...
#   94800/228340 inseridos...
#   94900/228340 inseridos...
#   95000/228340 inseridos...
#   95100/228340 inseridos...
#   95200/228340 inseridos...
#   95300/228340 inseridos...
#   95400/228340 inseridos...
#   95500/228340 inseridos...
#   95600/228340 inseridos...
#   95700/228340 inseridos...
#   95800/228340 inseridos...
#   95900/228340 inseridos...
#   96000/228340 inseridos...
#   96100/228340 inseridos...
#   96200/228340 inseridos...
#   96300/228340 inseridos...
#   96400/228340 inseridos...
#   96500/228340 inseridos...
#   96600/228340 inseridos...
#   96700/228340 inseridos...
#   96800/228340 inseridos...
#   96900/228340 inseridos...
#   97000/228340 inseridos...
#   97100/228340 inseridos...
#   97200/228340 inseridos...
#   97300/228340 inseridos...
#   97400/228340 inseridos...
#   97500/228340 inseridos...
#   97600/228340 inseridos...
#   97700/228340 inseridos...
#   97800/228340 inseridos...
#   97900/228340 inseridos...
#   98000/228340 inseridos...
#   98100/228340 inseridos...
#   98200/228340 inseridos...
#   98300/228340 inseridos...
#   98400/228340 inseridos...
#   98500/228340 inseridos...
#   98600/228340 inseridos...
#   98700/228340 inseridos...
#   98800/228340 inseridos...
#   98900/228340 inseridos...
#   99000/228340 inseridos...
#   99100/228340 inseridos...
#   99200/228340 inseridos...
#   99300/228340 inseridos...
#   99400/228340 inseridos...
#   99500/228340 inseridos...
#   99600/228340 inseridos...
#   99700/228340 inseridos...
#   99800/228340 inseridos...
#   99900/228340 inseridos...
#   100000/228340 inseridos...
#   100100/228340 inseridos...
#   100200/228340 inseridos...
#   100300/228340 inseridos...
#   100400/228340 inseridos...
#   100500/228340 inseridos...
#   100600/228340 inseridos...
#   100700/228340 inseridos...
#   100800/228340 inseridos...
#   100900/228340 inseridos...
#   101000/228340 inseridos...
#   101100/228340 inseridos...
#   101200/228340 inseridos...
#   101300/228340 inseridos...
#   101400/228340 inseridos...
#   101500/228340 inseridos...
#   101600/228340 inseridos...
#   101700/228340 inseridos...
#   101800/228340 inseridos...
#   101900/228340 inseridos...
#   102000/228340 inseridos...
#   102100/228340 inseridos...
#   102200/228340 inseridos...
#   102300/228340 inseridos...
#   102400/228340 inseridos...
#   102500/228340 inseridos...
#   102600/228340 inseridos...
#   102700/228340 inseridos...
#   102800/228340 inseridos...
#   102900/228340 inseridos...
#   103000/228340 inseridos...
#   103100/228340 inseridos...
#   103200/228340 inseridos...
#   103300/228340 inseridos...
#   103400/228340 inseridos...
#   103500/228340 inseridos...
#   103600/228340 inseridos...
#   103700/228340 inseridos...
#   103800/228340 inseridos...
#   103900/228340 inseridos...
#   104000/228340 inseridos...
#   104100/228340 inseridos...
#   104200/228340 inseridos...
#   104300/228340 inseridos...
#   104400/228340 inseridos...
#   104500/228340 inseridos...
#   104600/228340 inseridos...
#   104700/228340 inseridos...
#   104800/228340 inseridos...
#   104900/228340 inseridos...
#   105000/228340 inseridos...
#   105100/228340 inseridos...
#   105200/228340 inseridos...
#   105300/228340 inseridos...
#   105400/228340 inseridos...
#   105500/228340 inseridos...
#   105600/228340 inseridos...
#   105700/228340 inseridos...
#   105800/228340 inseridos...
#   105900/228340 inseridos...
#   106000/228340 inseridos...
#   106100/228340 inseridos...
#   106200/228340 inseridos...
#   106300/228340 inseridos...
#   106400/228340 inseridos...
#   106500/228340 inseridos...
#   106600/228340 inseridos...
#   106700/228340 inseridos...
#   106800/228340 inseridos...
#   106900/228340 inseridos...
#   107000/228340 inseridos...
#   107100/228340 inseridos...
#   107200/228340 inseridos...
#   107300/228340 inseridos...
#   107400/228340 inseridos...
#   107500/228340 inseridos...
#   107600/228340 inseridos...
#   107700/228340 inseridos...
#   107800/228340 inseridos...
#   107900/228340 inseridos...
#   108000/228340 inseridos...
#   108100/228340 inseridos...
#   108200/228340 inseridos...
#   108300/228340 inseridos...
#   108400/228340 inseridos...
#   108500/228340 inseridos...
#   108600/228340 inseridos...
#   108700/228340 inseridos...
#   108800/228340 inseridos...
#   108900/228340 inseridos...
#   109000/228340 inseridos...
#   109100/228340 inseridos...
#   109200/228340 inseridos...
#   109300/228340 inseridos...
#   109400/228340 inseridos...
#   109500/228340 inseridos...
#   109600/228340 inseridos...
#   109700/228340 inseridos...
#   109800/228340 inseridos...
#   109900/228340 inseridos...
#   110000/228340 inseridos...
#   110100/228340 inseridos...
#   110200/228340 inseridos...
#   110300/228340 inseridos...
#   110400/228340 inseridos...
#   110500/228340 inseridos...
#   110600/228340 inseridos...
#   110700/228340 inseridos...
#   110800/228340 inseridos...
#   110900/228340 inseridos...
#   111000/228340 inseridos...
#   111100/228340 inseridos...
#   111200/228340 inseridos...
#   111300/228340 inseridos...
#   111400/228340 inseridos...
#   111500/228340 inseridos...
#   111600/228340 inseridos...
#   111700/228340 inseridos...
#   111800/228340 inseridos...
#   111900/228340 inseridos...
#   112000/228340 inseridos...
#   112100/228340 inseridos...
#   112200/228340 inseridos...
#   112300/228340 inseridos...
#   112400/228340 inseridos...
#   112500/228340 inseridos...
#   112600/228340 inseridos...
#   112700/228340 inseridos...
#   112800/228340 inseridos...
#   112900/228340 inseridos...
#   113000/228340 inseridos...
#   113100/228340 inseridos...
#   113200/228340 inseridos...
#   113300/228340 inseridos...
#   113400/228340 inseridos...
#   113500/228340 inseridos...
#   113600/228340 inseridos...
#   113700/228340 inseridos...
#   113800/228340 inseridos...
#   113900/228340 inseridos...
#   114000/228340 inseridos...
#   114100/228340 inseridos...
#   114200/228340 inseridos...
#   114300/228340 inseridos...
#   114400/228340 inseridos...
#   114500/228340 inseridos...
#   114600/228340 inseridos...
#   114700/228340 inseridos...
#   114800/228340 inseridos...
#   114900/228340 inseridos...
#   115000/228340 inseridos...
#   115100/228340 inseridos...
#   115200/228340 inseridos...
#   115300/228340 inseridos...
#   115400/228340 inseridos...
#   115500/228340 inseridos...
#   115600/228340 inseridos...
#   115700/228340 inseridos...
#   115800/228340 inseridos...
#   115900/228340 inseridos...
#   116000/228340 inseridos...
#   116100/228340 inseridos...
#   116200/228340 inseridos...
#   116300/228340 inseridos...
#   116400/228340 inseridos...
#   116500/228340 inseridos...
#   116600/228340 inseridos...
#   116700/228340 inseridos...
#   116800/228340 inseridos...
#   116900/228340 inseridos...
#   117000/228340 inseridos...
#   117100/228340 inseridos...
#   117200/228340 inseridos...
#   117300/228340 inseridos...
#   117400/228340 inseridos...
#   117500/228340 inseridos...
#   117600/228340 inseridos...
#   117700/228340 inseridos...
#   117800/228340 inseridos...
#   117900/228340 inseridos...
#   118000/228340 inseridos...
#   118100/228340 inseridos...
#   118200/228340 inseridos...
#   118300/228340 inseridos...
#   118400/228340 inseridos...
#   118500/228340 inseridos...
#   118600/228340 inseridos...
#   118700/228340 inseridos...
#   118800/228340 inseridos...
#   118900/228340 inseridos...
#   119000/228340 inseridos...
#   119100/228340 inseridos...
#   119200/228340 inseridos...
#   119300/228340 inseridos...
#   119400/228340 inseridos...
#   119500/228340 inseridos...
#   119600/228340 inseridos...
#   119700/228340 inseridos...
#   119800/228340 inseridos...
#   119900/228340 inseridos...
#   120000/228340 inseridos...
#   120100/228340 inseridos...
#   120200/228340 inseridos...
#   120300/228340 inseridos...
#   120400/228340 inseridos...
#   120500/228340 inseridos...
#   120600/228340 inseridos...
#   120700/228340 inseridos...
#   120800/228340 inseridos...
#   120900/228340 inseridos...
#   121000/228340 inseridos...
#   121100/228340 inseridos...
#   121200/228340 inseridos...
#   121300/228340 inseridos...
#   121400/228340 inseridos...
#   121500/228340 inseridos...
#   121600/228340 inseridos...
#   121700/228340 inseridos...
#   121800/228340 inseridos...
#   121900/228340 inseridos...
#   122000/228340 inseridos...
#   122100/228340 inseridos...
#   122200/228340 inseridos...
#   122300/228340 inseridos...
#   122400/228340 inseridos...
#   122500/228340 inseridos...
#   122600/228340 inseridos...
#   122700/228340 inseridos...
#   122800/228340 inseridos...
#   122900/228340 inseridos...
#   123000/228340 inseridos...
#   123100/228340 inseridos...
#   123200/228340 inseridos...
#   123300/228340 inseridos...
#   123400/228340 inseridos...
#   123500/228340 inseridos...
#   123600/228340 inseridos...
#   123700/228340 inseridos...
#   123800/228340 inseridos...
#   123900/228340 inseridos...
#   124000/228340 inseridos...
#   124100/228340 inseridos...
#   124200/228340 inseridos...
#   124300/228340 inseridos...
#   124400/228340 inseridos...
#   124500/228340 inseridos...
#   124600/228340 inseridos...
#   124700/228340 inseridos...
#   124800/228340 inseridos...
#   124900/228340 inseridos...
#   125000/228340 inseridos...
#   125100/228340 inseridos...
#   125200/228340 inseridos...
#   125300/228340 inseridos...
#   125400/228340 inseridos...
#   125500/228340 inseridos...
#   125600/228340 inseridos...
#   125700/228340 inseridos...
#   125800/228340 inseridos...
#   125900/228340 inseridos...
#   126000/228340 inseridos...
#   126100/228340 inseridos...
#   126200/228340 inseridos...
#   126300/228340 inseridos...
#   126400/228340 inseridos...
#   126500/228340 inseridos...
#   126600/228340 inseridos...
#   126700/228340 inseridos...
#   126800/228340 inseridos...
#   126900/228340 inseridos...
#   127000/228340 inseridos...
#   127100/228340 inseridos...
#   127200/228340 inseridos...
#   127300/228340 inseridos...
#   127400/228340 inseridos...
#   127500/228340 inseridos...
#   127600/228340 inseridos...
#   127700/228340 inseridos...
#   127800/228340 inseridos...
#   127900/228340 inseridos...
#   128000/228340 inseridos...
#   128100/228340 inseridos...
#   128200/228340 inseridos...
#   128300/228340 inseridos...
#   128400/228340 inseridos...
#   128500/228340 inseridos...
#   128600/228340 inseridos...
#   128700/228340 inseridos...
#   128800/228340 inseridos...
#   128900/228340 inseridos...
#   129000/228340 inseridos...
#   129100/228340 inseridos...
#   129200/228340 inseridos...
#   129300/228340 inseridos...
#   129400/228340 inseridos...
#   129500/228340 inseridos...
#   129600/228340 inseridos...
#   129700/228340 inseridos...
#   129800/228340 inseridos...
#   129900/228340 inseridos...
#   130000/228340 inseridos...
#   130100/228340 inseridos...
#   130200/228340 inseridos...
#   130300/228340 inseridos...
#   130400/228340 inseridos...
#   130500/228340 inseridos...
#   130600/228340 inseridos...
#   130700/228340 inseridos...
#   130800/228340 inseridos...
#   130900/228340 inseridos...
#   131000/228340 inseridos...
#   131100/228340 inseridos...
#   131200/228340 inseridos...
#   131300/228340 inseridos...
#   131400/228340 inseridos...
#   131500/228340 inseridos...
#   131600/228340 inseridos...
#   131700/228340 inseridos...
#   131800/228340 inseridos...
#   131900/228340 inseridos...
#   132000/228340 inseridos...
#   132100/228340 inseridos...
#   132200/228340 inseridos...
#   132300/228340 inseridos...
#   132400/228340 inseridos...
#   132500/228340 inseridos...
#   132600/228340 inseridos...
#   132700/228340 inseridos...
#   132800/228340 inseridos...
#   132900/228340 inseridos...
#   133000/228340 inseridos...
#   133100/228340 inseridos...
#   133200/228340 inseridos...
#   133300/228340 inseridos...
#   133400/228340 inseridos...
#   133500/228340 inseridos...
#   133600/228340 inseridos...
#   133700/228340 inseridos...
#   133800/228340 inseridos...
#   133900/228340 inseridos...
#   134000/228340 inseridos...
#   134100/228340 inseridos...
#   134200/228340 inseridos...
#   134300/228340 inseridos...
#   134400/228340 inseridos...
#   134500/228340 inseridos...
#   134600/228340 inseridos...
#   134700/228340 inseridos...
#   134800/228340 inseridos...
#   134900/228340 inseridos...
#   135000/228340 inseridos...
#   135100/228340 inseridos...
#   135200/228340 inseridos...
#   135300/228340 inseridos...
#   135400/228340 inseridos...
#   135500/228340 inseridos...
#   135600/228340 inseridos...
#   135700/228340 inseridos...
#   135800/228340 inseridos...
#   135900/228340 inseridos...
#   136000/228340 inseridos...
#   136100/228340 inseridos...
#   136200/228340 inseridos...
#   136300/228340 inseridos...
#   136400/228340 inseridos...
#   136500/228340 inseridos...
#   136600/228340 inseridos...
#   136700/228340 inseridos...
#   136800/228340 inseridos...
#   136900/228340 inseridos...
#   137000/228340 inseridos...
#   137100/228340 inseridos...
#   137200/228340 inseridos...
#   137300/228340 inseridos...
#   137400/228340 inseridos...
#   137500/228340 inseridos...
#   137600/228340 inseridos...
#   137700/228340 inseridos...
#   137800/228340 inseridos...
#   137900/228340 inseridos...
#   138000/228340 inseridos...
#   138100/228340 inseridos...
#   138200/228340 inseridos...
#   138300/228340 inseridos...
#   138400/228340 inseridos...
#   138500/228340 inseridos...
#   138600/228340 inseridos...
#   138700/228340 inseridos...
#   138800/228340 inseridos...
#   138900/228340 inseridos...
#   139000/228340 inseridos...
#   139100/228340 inseridos...
#   139200/228340 inseridos...
#   139300/228340 inseridos...
#   139400/228340 inseridos...
#   139500/228340 inseridos...
#   139600/228340 inseridos...
#   139700/228340 inseridos...
#   139800/228340 inseridos...
#   139900/228340 inseridos...
#   140000/228340 inseridos...
#   140100/228340 inseridos...
#   140200/228340 inseridos...
#   140300/228340 inseridos...
#   140400/228340 inseridos...
#   140500/228340 inseridos...
#   140600/228340 inseridos...
#   140700/228340 inseridos...
#   140800/228340 inseridos...
#   140900/228340 inseridos...
#   141000/228340 inseridos...
#   141100/228340 inseridos...
#   141200/228340 inseridos...
#   141300/228340 inseridos...
#   141400/228340 inseridos...
#   141500/228340 inseridos...
#   141600/228340 inseridos...
#   141700/228340 inseridos...
#   141800/228340 inseridos...
#   141900/228340 inseridos...
#   142000/228340 inseridos...
#   142100/228340 inseridos...
#   142200/228340 inseridos...
#   142300/228340 inseridos...
#   142400/228340 inseridos...
#   142500/228340 inseridos...
#   142600/228340 inseridos...
#   142700/228340 inseridos...
#   142800/228340 inseridos...
#   142900/228340 inseridos...
#   143000/228340 inseridos...
#   143100/228340 inseridos...
#   143200/228340 inseridos...
#   143300/228340 inseridos...
#   143400/228340 inseridos...
#   143500/228340 inseridos...
#   143600/228340 inseridos...
#   143700/228340 inseridos...
#   143800/228340 inseridos...
#   143900/228340 inseridos...
#   144000/228340 inseridos...
#   144100/228340 inseridos...
#   144200/228340 inseridos...
#   144300/228340 inseridos...
#   144400/228340 inseridos...
#   144500/228340 inseridos...
#   144600/228340 inseridos...
#   144700/228340 inseridos...
#   144800/228340 inseridos...
#   144900/228340 inseridos...
#   145000/228340 inseridos...
#   145100/228340 inseridos...
#   145200/228340 inseridos...
#   145300/228340 inseridos...
#   145400/228340 inseridos...
#   145500/228340 inseridos...
#   145600/228340 inseridos...
#   145700/228340 inseridos...
#   145800/228340 inseridos...
#   145900/228340 inseridos...
#   146000/228340 inseridos...
#   146100/228340 inseridos...
#   146200/228340 inseridos...
#   146300/228340 inseridos...
#   146400/228340 inseridos...
#   146500/228340 inseridos...
#   146600/228340 inseridos...
#   146700/228340 inseridos...
#   146800/228340 inseridos...
#   146900/228340 inseridos...
#   147000/228340 inseridos...
#   147100/228340 inseridos...
#   147200/228340 inseridos...
#   147300/228340 inseridos...
#   147400/228340 inseridos...
#   147500/228340 inseridos...
#   147600/228340 inseridos...
#   147700/228340 inseridos...
#   147800/228340 inseridos...
#   147900/228340 inseridos...
#   148000/228340 inseridos...
#   148100/228340 inseridos...
#   148200/228340 inseridos...
#   148300/228340 inseridos...
#   148400/228340 inseridos...
#   148500/228340 inseridos...
#   148600/228340 inseridos...
#   148700/228340 inseridos...
#   148800/228340 inseridos...
#   148900/228340 inseridos...
#   149000/228340 inseridos...
#   149100/228340 inseridos...
#   149200/228340 inseridos...
#   149300/228340 inseridos...
#   149400/228340 inseridos...
#   149500/228340 inseridos...
#   149600/228340 inseridos...
#   149700/228340 inseridos...
#   149800/228340 inseridos...
#   149900/228340 inseridos...
#   150000/228340 inseridos...
#   150100/228340 inseridos...
#   150200/228340 inseridos...
#   150300/228340 inseridos...
#   150400/228340 inseridos...
#   150500/228340 inseridos...
#   150600/228340 inseridos...
#   150700/228340 inseridos...
#   150800/228340 inseridos...
#   150900/228340 inseridos...
#   151000/228340 inseridos...
#   151100/228340 inseridos...
#   151200/228340 inseridos...
#   151300/228340 inseridos...
#   151400/228340 inseridos...
#   151500/228340 inseridos...
#   151600/228340 inseridos...
#   151700/228340 inseridos...
#   151800/228340 inseridos...
#   151900/228340 inseridos...
#   152000/228340 inseridos...
#   152100/228340 inseridos...
#   152200/228340 inseridos...
#   152300/228340 inseridos...
#   152400/228340 inseridos...
#   152500/228340 inseridos...
#   152600/228340 inseridos...
#   152700/228340 inseridos...
#   152800/228340 inseridos...
#   152900/228340 inseridos...
#   153000/228340 inseridos...
#   153100/228340 inseridos...
#   153200/228340 inseridos...
#   153300/228340 inseridos...
#   153400/228340 inseridos...
#   153500/228340 inseridos...
#   153600/228340 inseridos...
#   153700/228340 inseridos...
#   153800/228340 inseridos...
#   153900/228340 inseridos...
#   154000/228340 inseridos...
#   154100/228340 inseridos...
#   154200/228340 inseridos...
#   154300/228340 inseridos...
#   154400/228340 inseridos...
#   154500/228340 inseridos...
#   154600/228340 inseridos...
#   154700/228340 inseridos...
#   154800/228340 inseridos...
#   154900/228340 inseridos...
#   155000/228340 inseridos...
#   155100/228340 inseridos...
#   155200/228340 inseridos...
#   155300/228340 inseridos...
#   155400/228340 inseridos...
#   155500/228340 inseridos...
#   155600/228340 inseridos...
#   155700/228340 inseridos...
#   155800/228340 inseridos...
#   155900/228340 inseridos...
#   156000/228340 inseridos...
#   156100/228340 inseridos...
#   156200/228340 inseridos...
#   156300/228340 inseridos...
#   156400/228340 inseridos...
#   156500/228340 inseridos...
#   156600/228340 inseridos...
#   156700/228340 inseridos...
#   156800/228340 inseridos...
#   156900/228340 inseridos...
#   157000/228340 inseridos...
#   157100/228340 inseridos...
#   157200/228340 inseridos...
#   157300/228340 inseridos...
#   157400/228340 inseridos...
#   157500/228340 inseridos...
#   157600/228340 inseridos...
#   157700/228340 inseridos...
#   157800/228340 inseridos...
#   157900/228340 inseridos...
#   158000/228340 inseridos...
#   158100/228340 inseridos...
#   158200/228340 inseridos...
#   158300/228340 inseridos...
#   158400/228340 inseridos...
#   158500/228340 inseridos...
#   158600/228340 inseridos...
#   158700/228340 inseridos...
#   158800/228340 inseridos...
#   158900/228340 inseridos...
#   159000/228340 inseridos...
#   159100/228340 inseridos...
#   159200/228340 inseridos...
#   159300/228340 inseridos...
#   159400/228340 inseridos...
#   159500/228340 inseridos...
#   159600/228340 inseridos...
#   159700/228340 inseridos...
#   159800/228340 inseridos...
#   159900/228340 inseridos...
#   160000/228340 inseridos...
#   160100/228340 inseridos...
#   160200/228340 inseridos...
#   160300/228340 inseridos...
#   160400/228340 inseridos...
#   160500/228340 inseridos...
#   160600/228340 inseridos...
#   160700/228340 inseridos...
#   160800/228340 inseridos...
#   160900/228340 inseridos...
#   161000/228340 inseridos...
#   161100/228340 inseridos...
#   161200/228340 inseridos...
#   161300/228340 inseridos...
#   161400/228340 inseridos...
#   161500/228340 inseridos...
#   161600/228340 inseridos...
#   161700/228340 inseridos...
#   161800/228340 inseridos...
#   161900/228340 inseridos...
#   162000/228340 inseridos...
#   162100/228340 inseridos...
#   162200/228340 inseridos...
#   162300/228340 inseridos...
#   162400/228340 inseridos...
#   162500/228340 inseridos...
#   162600/228340 inseridos...
#   162700/228340 inseridos...
#   162800/228340 inseridos...
#   162900/228340 inseridos...
#   163000/228340 inseridos...
#   163100/228340 inseridos...
#   163200/228340 inseridos...
#   163300/228340 inseridos...
#   163400/228340 inseridos...
#   163500/228340 inseridos...
#   163600/228340 inseridos...
#   163700/228340 inseridos...
#   163800/228340 inseridos...
#   163900/228340 inseridos...
#   164000/228340 inseridos...
#   164100/228340 inseridos...
#   164200/228340 inseridos...
#   164300/228340 inseridos...
#   164400/228340 inseridos...
#   164500/228340 inseridos...
#   164600/228340 inseridos...
#   164700/228340 inseridos...
#   164800/228340 inseridos...
#   164900/228340 inseridos...
#   165000/228340 inseridos...
#   165100/228340 inseridos...
#   165200/228340 inseridos...
#   165300/228340 inseridos...
#   165400/228340 inseridos...
#   165500/228340 inseridos...
#   165600/228340 inseridos...
#   165700/228340 inseridos...
#   165800/228340 inseridos...
#   165900/228340 inseridos...
#   166000/228340 inseridos...
#   166100/228340 inseridos...
#   166200/228340 inseridos...
#   166300/228340 inseridos...
#   166400/228340 inseridos...
#   166500/228340 inseridos...
#   166600/228340 inseridos...
#   166700/228340 inseridos...
#   166800/228340 inseridos...
#   166900/228340 inseridos...
#   167000/228340 inseridos...
#   167100/228340 inseridos...
#   167200/228340 inseridos...
#   167300/228340 inseridos...
#   167400/228340 inseridos...
#   167500/228340 inseridos...
#   167600/228340 inseridos...
#   167700/228340 inseridos...
#   167800/228340 inseridos...
#   167900/228340 inseridos...
#   168000/228340 inseridos...
#   168100/228340 inseridos...
#   168200/228340 inseridos...
#   168300/228340 inseridos...
#   168400/228340 inseridos...
#   168500/228340 inseridos...
#   168600/228340 inseridos...
#   168700/228340 inseridos...
#   168800/228340 inseridos...
#   168900/228340 inseridos...
# ...
#   173700/228340 inseridos...
#   173800/228340 inseridos...
#   173900/228340 inseridos...
#   174000/228340 inseridos...
#   174100/228340 inseridos...
#   174200/228340 inseridos...
#   174300/228340 inseridos...
#   174400/228340 inseridos...
#   174500/228340 inseridos...
#   174600/228340 inseridos...
#   174700/228340 inseridos...
#   174800/228340 inseridos...
#   174900/228340 inseridos...
#   175000/228340 inseridos...
#   175100/228340 inseridos...
#   175200/228340 inseridos...
#   175300/228340 inseridos...
#   175400/228340 inseridos...
#   175500/228340 inseridos...
#   175600/228340 inseridos...
#   175700/228340 inseridos...
#   175800/228340 inseridos...
#   175900/228340 inseridos...
#   176000/228340 inseridos...
#   176100/228340 inseridos...
#   176200/228340 inseridos...
#   176300/228340 inseridos...
#   176400/228340 inseridos...
#   176500/228340 inseridos...
#   176600/228340 inseridos...
#   176700/228340 inseridos...
#   176800/228340 inseridos...
#   176900/228340 inseridos...
#   177000/228340 inseridos...
#   177100/228340 inseridos...
#   177200/228340 inseridos...
#   177300/228340 inseridos...
#   177400/228340 inseridos...
#   177500/228340 inseridos...
#   177600/228340 inseridos...
#   177700/228340 inseridos...
#   177800/228340 inseridos...
#   177900/228340 inseridos...
#   178000/228340 inseridos...
#   178100/228340 inseridos...
#   178200/228340 inseridos...
#   178300/228340 inseridos...
#   178400/228340 inseridos...
#   178500/228340 inseridos...
#   178600/228340 inseridos...
#   178700/228340 inseridos...
#   178800/228340 inseridos...
#   178900/228340 inseridos...
#   179000/228340 inseridos...
#   179100/228340 inseridos...
#   179200/228340 inseridos...
#   179300/228340 inseridos...
#   179400/228340 inseridos...
#   179500/228340 inseridos...
#   179600/228340 inseridos...
#   179700/228340 inseridos...
#   179800/228340 inseridos...
#   179900/228340 inseridos...
#   180000/228340 inseridos...
#   180100/228340 inseridos...
#   180200/228340 inseridos...
#   180300/228340 inseridos...
#   180400/228340 inseridos...
#   180500/228340 inseridos...
#   180600/228340 inseridos...
#   180700/228340 inseridos...
#   180800/228340 inseridos...
#   180900/228340 inseridos...
#   181000/228340 inseridos...
#   181100/228340 inseridos...
#   181200/228340 inseridos...
#   181300/228340 inseridos...
#   181400/228340 inseridos...
#   181500/228340 inseridos...
#   181600/228340 inseridos...
#   181700/228340 inseridos...
#   181800/228340 inseridos...
#   181900/228340 inseridos...
#   182000/228340 inseridos...
#   182100/228340 inseridos...
#   182200/228340 inseridos...
#   182300/228340 inseridos...
#   182400/228340 inseridos...
#   182500/228340 inseridos...
#   182600/228340 inseridos...
#   182700/228340 inseridos...
#   182800/228340 inseridos...
#   182900/228340 inseridos...
#   183000/228340 inseridos...
#   183100/228340 inseridos...
#   183200/228340 inseridos...
#   183300/228340 inseridos...
#   183400/228340 inseridos...
#   183500/228340 inseridos...
#   183600/228340 inseridos...
#   183700/228340 inseridos...
#   183800/228340 inseridos...
#   183900/228340 inseridos...
#   184000/228340 inseridos...
#   184100/228340 inseridos...
#   184200/228340 inseridos...
#   184300/228340 inseridos...
#   184400/228340 inseridos...
#   184500/228340 inseridos...
#   184600/228340 inseridos...
#   184700/228340 inseridos...
#   184800/228340 inseridos...
#   184900/228340 inseridos...
#   185000/228340 inseridos...
#   185100/228340 inseridos...
#   185200/228340 inseridos...
#   185300/228340 inseridos...
#   185400/228340 inseridos...
#   185500/228340 inseridos...
#   185600/228340 inseridos...
#   185700/228340 inseridos...
#   185800/228340 inseridos...
#   185900/228340 inseridos...
#   186000/228340 inseridos...
#   186100/228340 inseridos...
#   186200/228340 inseridos...
#   186300/228340 inseridos...
#   186400/228340 inseridos...
#   186500/228340 inseridos...
#   186600/228340 inseridos...
#   186700/228340 inseridos...
#   186800/228340 inseridos...
#   186900/228340 inseridos...
#   187000/228340 inseridos...
#   187100/228340 inseridos...
#   187200/228340 inseridos...
#   187300/228340 inseridos...
#   187400/228340 inseridos...
#   187500/228340 inseridos...
#   187600/228340 inseridos...
#   187700/228340 inseridos...
#   187800/228340 inseridos...
#   187900/228340 inseridos...
#   188000/228340 inseridos...
#   188100/228340 inseridos...
#   188200/228340 inseridos...
#   188300/228340 inseridos...
#   188400/228340 inseridos...
#   188500/228340 inseridos...
#   188600/228340 inseridos...
#   188700/228340 inseridos...
#   188800/228340 inseridos...
#   188900/228340 inseridos...
#   189000/228340 inseridos...
#   189100/228340 inseridos...
#   189200/228340 inseridos...
#   189300/228340 inseridos...
#   189400/228340 inseridos...
#   189500/228340 inseridos...
#   189600/228340 inseridos...
#   189700/228340 inseridos...
#   189800/228340 inseridos...
#   189900/228340 inseridos...
#   190000/228340 inseridos...
#   190100/228340 inseridos...
#   190200/228340 inseridos...
#   190300/228340 inseridos...
#   190400/228340 inseridos...
#   190500/228340 inseridos...
#   190600/228340 inseridos...
#   190700/228340 inseridos...
#   190800/228340 inseridos...
#   190900/228340 inseridos...
#   191000/228340 inseridos...
#   191100/228340 inseridos...
#   191200/228340 inseridos...
#   191300/228340 inseridos...
#   191400/228340 inseridos...
#   191500/228340 inseridos...
#   191600/228340 inseridos...
#   191700/228340 inseridos...
#   191800/228340 inseridos...
#   191900/228340 inseridos...
#   192000/228340 inseridos...
#   192100/228340 inseridos...
#   192200/228340 inseridos...
#   192300/228340 inseridos...
#   192400/228340 inseridos...
#   192500/228340 inseridos...
#   192600/228340 inseridos...
#   192700/228340 inseridos...
#   192800/228340 inseridos...
#   192900/228340 inseridos...
#   193000/228340 inseridos...
#   193100/228340 inseridos...
#   193200/228340 inseridos...
#   193300/228340 inseridos...
#   193400/228340 inseridos...
#   193500/228340 inseridos...
#   193600/228340 inseridos...
#   193700/228340 inseridos...
#   193800/228340 inseridos...
#   193900/228340 inseridos...
#   194000/228340 inseridos...
#   194100/228340 inseridos...
#   194200/228340 inseridos...
#   194300/228340 inseridos...
#   194400/228340 inseridos...
#   194500/228340 inseridos...
#   194600/228340 inseridos...
#   194700/228340 inseridos...
#   194800/228340 inseridos...
#   194900/228340 inseridos...
#   195000/228340 inseridos...
#   195100/228340 inseridos...
#   195200/228340 inseridos...
#   195300/228340 inseridos...
#   195400/228340 inseridos...
#   195500/228340 inseridos...
#   195600/228340 inseridos...
#   195700/228340 inseridos...
#   195800/228340 inseridos...
#   195900/228340 inseridos...
#   196000/228340 inseridos...
#   196100/228340 inseridos...
#   196200/228340 inseridos...
#   196300/228340 inseridos...
#   196400/228340 inseridos...
#   196500/228340 inseridos...
#   196600/228340 inseridos...
#   196700/228340 inseridos...
#   196800/228340 inseridos...
#   196900/228340 inseridos...
#   197000/228340 inseridos...
#   197100/228340 inseridos...
#   197200/228340 inseridos...
#   197300/228340 inseridos...
#   197400/228340 inseridos...
#   197500/228340 inseridos...
#   197600/228340 inseridos...
#   197700/228340 inseridos...
#   197800/228340 inseridos...
#   197900/228340 inseridos...
#   198000/228340 inseridos...
#   198100/228340 inseridos...
#   198200/228340 inseridos...
#   198300/228340 inseridos...
#   198400/228340 inseridos...
#   198500/228340 inseridos...
#   198600/228340 inseridos...
#   198700/228340 inseridos...
#   198800/228340 inseridos...
#   198900/228340 inseridos...
#   199000/228340 inseridos...
#   199100/228340 inseridos...
#   199200/228340 inseridos...
#   199300/228340 inseridos...
#   199400/228340 inseridos...
#   199500/228340 inseridos...
#   199600/228340 inseridos...
#   199700/228340 inseridos...
#   199800/228340 inseridos...
#   199900/228340 inseridos...
#   200000/228340 inseridos...
#   200100/228340 inseridos...
#   200200/228340 inseridos...
#   200300/228340 inseridos...
#   200400/228340 inseridos...
#   200500/228340 inseridos...
#   200600/228340 inseridos...
#   200700/228340 inseridos...
#   200800/228340 inseridos...
#   200900/228340 inseridos...
#   201000/228340 inseridos...
#   201100/228340 inseridos...
#   201200/228340 inseridos...
#   201300/228340 inseridos...
#   201400/228340 inseridos...
#   201500/228340 inseridos...
#   201600/228340 inseridos...
#   201700/228340 inseridos...
#   201800/228340 inseridos...
#   201900/228340 inseridos...
#   202000/228340 inseridos...
#   202100/228340 inseridos...
#   202200/228340 inseridos...
#   202300/228340 inseridos...
#   202400/228340 inseridos...
#   202500/228340 inseridos...
#   202600/228340 inseridos...
#   202700/228340 inseridos...
#   202800/228340 inseridos...
#   202900/228340 inseridos...
#   203000/228340 inseridos...
#   203100/228340 inseridos...
#   203200/228340 inseridos...
#   203300/228340 inseridos...
#   203400/228340 inseridos...
#   203500/228340 inseridos...
#   203600/228340 inseridos...
#   203700/228340 inseridos...
#   203800/228340 inseridos...
#   203900/228340 inseridos...
#   204000/228340 inseridos...
#   204100/228340 inseridos...
#   204200/228340 inseridos...
#   204300/228340 inseridos...
#   204400/228340 inseridos...
#   204500/228340 inseridos...
#   204600/228340 inseridos...
#   204700/228340 inseridos...
#   204800/228340 inseridos...
#   204900/228340 inseridos...
#   205000/228340 inseridos...
#   205100/228340 inseridos...
#   205200/228340 inseridos...
#   205300/228340 inseridos...
#   205400/228340 inseridos...
#   205500/228340 inseridos...
#   205600/228340 inseridos...
#   205700/228340 inseridos...
#   205800/228340 inseridos...
#   205900/228340 inseridos...
#   206000/228340 inseridos...
#   206100/228340 inseridos...
#   206200/228340 inseridos...
#   206300/228340 inseridos...
#   206400/228340 inseridos...
#   206500/228340 inseridos...
#   206600/228340 inseridos...
#   206700/228340 inseridos...
#   206800/228340 inseridos...
#   206900/228340 inseridos...
#   207000/228340 inseridos...
#   207100/228340 inseridos...
#   207200/228340 inseridos...
#   207300/228340 inseridos...
#   207400/228340 inseridos...
#   207500/228340 inseridos...
#   207600/228340 inseridos...
#   207700/228340 inseridos...
#   207800/228340 inseridos...
#   207900/228340 inseridos...
#   208000/228340 inseridos...
#   208100/228340 inseridos...
#   208200/228340 inseridos...
#   208300/228340 inseridos...
#   208400/228340 inseridos...
#   208500/228340 inseridos...
#   208600/228340 inseridos...
#   208700/228340 inseridos...
#   208800/228340 inseridos...
#   208900/228340 inseridos...
#   209000/228340 inseridos...
#   209100/228340 inseridos...
#   209200/228340 inseridos...
#   209300/228340 inseridos...
#   209400/228340 inseridos...
#   209500/228340 inseridos...
#   209600/228340 inseridos...
#   209700/228340 inseridos...
#   209800/228340 inseridos...
#   209900/228340 inseridos...
#   210000/228340 inseridos...
#   210100/228340 inseridos...
#   210200/228340 inseridos...
#   210300/228340 inseridos...
#   210400/228340 inseridos...
#   210500/228340 inseridos...
#   210600/228340 inseridos...
#   210700/228340 inseridos...
#   210800/228340 inseridos...
#   210900/228340 inseridos...
#   211000/228340 inseridos...
#   211100/228340 inseridos...
#   211200/228340 inseridos...
#   211300/228340 inseridos...
#   211400/228340 inseridos...
#   211500/228340 inseridos...
#   211600/228340 inseridos...
#   211700/228340 inseridos...
#   211800/228340 inseridos...
#   211900/228340 inseridos...
#   212000/228340 inseridos...
#   212100/228340 inseridos...
#   212200/228340 inseridos...
#   212300/228340 inseridos...
#   212400/228340 inseridos...
#   212500/228340 inseridos...
#   212600/228340 inseridos...
#   212700/228340 inseridos...
#   212800/228340 inseridos...
#   212900/228340 inseridos...
#   213000/228340 inseridos...
#   213100/228340 inseridos...
#   213200/228340 inseridos...
#   213300/228340 inseridos...
#   213400/228340 inseridos...
#   213500/228340 inseridos...
#   213600/228340 inseridos...
#   213700/228340 inseridos...
#   213800/228340 inseridos...
#   213900/228340 inseridos...
#   214000/228340 inseridos...
#   214100/228340 inseridos...
#   214200/228340 inseridos...
#   214300/228340 inseridos...
#   214400/228340 inseridos...
#   214500/228340 inseridos...
#   214600/228340 inseridos...
#   214700/228340 inseridos...
#   214800/228340 inseridos...
#   214900/228340 inseridos...
#   215000/228340 inseridos...
#   215100/228340 inseridos...
#   215200/228340 inseridos...
#   215300/228340 inseridos...
#   215400/228340 inseridos...
#   215500/228340 inseridos...
#   215600/228340 inseridos...
#   215700/228340 inseridos...
#   215800/228340 inseridos...
#   215900/228340 inseridos...
#   216000/228340 inseridos...
#   216100/228340 inseridos...
#   216200/228340 inseridos...
#   216300/228340 inseridos...
#   216400/228340 inseridos...
#   216500/228340 inseridos...
#   216600/228340 inseridos...
#   216700/228340 inseridos...
#   216800/228340 inseridos...
#   216900/228340 inseridos...
#   217000/228340 inseridos...
#   217100/228340 inseridos...
#   217200/228340 inseridos...
#   217300/228340 inseridos...
#   217400/228340 inseridos...
#   217500/228340 inseridos...
#   217600/228340 inseridos...
#   217700/228340 inseridos...
#   217800/228340 inseridos...
#   217900/228340 inseridos...
#   218000/228340 inseridos...
#   218100/228340 inseridos...
#   218200/228340 inseridos...
#   218300/228340 inseridos...
#   218400/228340 inseridos...
#   218500/228340 inseridos...
#   218600/228340 inseridos...
#   218700/228340 inseridos...
#   218800/228340 inseridos...
#   218900/228340 inseridos...
#   219000/228340 inseridos...
#   219100/228340 inseridos...
#   219200/228340 inseridos...
#   219300/228340 inseridos...
#   219400/228340 inseridos...
#   219500/228340 inseridos...
#   219600/228340 inseridos...
#   219700/228340 inseridos...
#   219800/228340 inseridos...
#   219900/228340 inseridos...
#   220000/228340 inseridos...
#   220100/228340 inseridos...
#   220200/228340 inseridos...
#   220300/228340 inseridos...
#   220400/228340 inseridos...
#   220500/228340 inseridos...
#   220600/228340 inseridos...
#   220700/228340 inseridos...
#   220800/228340 inseridos...
#   220900/228340 inseridos...
#   221000/228340 inseridos...
#   221100/228340 inseridos...
#   221200/228340 inseridos...
#   221300/228340 inseridos...
#   221400/228340 inseridos...
#   221500/228340 inseridos...
#   221600/228340 inseridos...
#   221700/228340 inseridos...
#   221800/228340 inseridos...
#   221900/228340 inseridos...
#   222000/228340 inseridos...
#   222100/228340 inseridos...
#   222200/228340 inseridos...
#   222300/228340 inseridos...
#   222400/228340 inseridos...
#   222500/228340 inseridos...
#   222600/228340 inseridos...
#   222700/228340 inseridos...
#   222800/228340 inseridos...
#   222900/228340 inseridos...
#   223000/228340 inseridos...
#   223100/228340 inseridos...
#   223200/228340 inseridos...
#   223300/228340 inseridos...
#   223400/228340 inseridos...
#   223500/228340 inseridos...
#   223600/228340 inseridos...
#   223700/228340 inseridos...
#   223800/228340 inseridos...
#   223900/228340 inseridos...
#   224000/228340 inseridos...
#   224100/228340 inseridos...
#   224200/228340 inseridos...
#   224300/228340 inseridos...
#   224400/228340 inseridos...
#   224500/228340 inseridos...
#   224600/228340 inseridos...
#   224700/228340 inseridos...
#   224800/228340 inseridos...
#   224900/228340 inseridos...
#   225000/228340 inseridos...
#   225100/228340 inseridos...
#   225200/228340 inseridos...
#   225300/228340 inseridos...
#   225400/228340 inseridos...
#   225500/228340 inseridos...
#   225600/228340 inseridos...
#   225700/228340 inseridos...
#   225800/228340 inseridos...
#   225900/228340 inseridos...
#   226000/228340 inseridos...
#   226100/228340 inseridos...
#   226200/228340 inseridos...
#   226300/228340 inseridos...
#   226400/228340 inseridos...
#   226500/228340 inseridos...
#   226600/228340 inseridos...
#   226700/228340 inseridos...
#   226800/228340 inseridos...
#   226900/228340 inseridos...
#   227000/228340 inseridos...
#   227100/228340 inseridos...
#   227200/228340 inseridos...
#   227300/228340 inseridos...
#   227400/228340 inseridos...
#   227500/228340 inseridos...
#   227600/228340 inseridos...
#   227700/228340 inseridos...
#   227800/228340 inseridos...
#   227900/228340 inseridos...
#   228000/228340 inseridos...
#   228100/228340 inseridos...
#   228200/228340 inseridos...
#   228300/228340 inseridos...
#   228340/228340 inseridos...
# ========================================
# Criados:   228340
# Ignorados: 17817
# Erros:     0

# %%
payload = models.execute_kw(
    db, uid, password,
    "calculadora.price.line",
    "get_data_js_payload",
    [[["cod_preven", "=", 155], ["produto", "=", "ADANA"]]]
)

payload["produtos"].keys()
# Out:
# dict_keys(['ADANA'])

# %%
payload["produtos"]["ADANA"][:2]
# Out:
# [{'m': '1B + PUFF BI',
#   'med': 'C:1.00M + 0.80M × P:0.97M',
#   'acab': 'BASE: PINTURA FOSCA',
#   'emb': 'CAIXA MADEIRA',
#   'd': 'ADANA MOD: 1B + PUFF BI COMP: 1.00M + 0.80M PROF: 0.97M',
#   '$': {'B': 5417.0,
#    'C': 5569.0,
#    'D': 5776.0,
#    'E': 5884.0,
#    'F': 5993.0,
#    'FORNECIDO': 5417.0,
#    'G': 6193.0,
#    'H': 6613.0,
#    'I': 7150.0,
#    'J': 8973.0},
#   '_precoIds': {'B': 11588595,
#    'C': 11588621,
#    'D': 11588649,
#    'E': 11588674,
#    'F': 11588727,
#    'FORNECIDO': 11588700,
#    'G': 11588753,
#    'H': 11588778,
#    'I': 11588804,
#    'J': 11588830}},
#  {'m': '1B + PUFF BI',
#   'med': 'C:1.00M + 0.80M × P:0.97M',
#   'acab': 'BASE: PINTURA FOSCA',
#   'emb': 'SEM CX MADEIRA',
#   'd': 'ADANA MOD: 1B + PUFF BI COMP: 1.00M + 0.80M PROF: 0.97M',
#   '$': {'B': 5177.0,
#    'C': 5329.0,
#    'D': 5536.0,
#    'E': 5644.0,
#    'F': 5752.0,
#    'FORNECIDO': 5177.0,
#    'G': 5953.0,
#    'H': 6373.0,
#    'I': 6910.0,
#    'J': 8733.0},
#   '_precoIds': {'B': 11588599,
#    'C': 11588625,
#    'D': 11588655,
#    'E': 11588679,
#    'F': 11588731,
#    'FORNECIDO': 11588705,
#    'G': 11588757,
#    'H': 11588784,
#    'I': 11588808,
#    'J': 11588835}}]

# %%
#trep_focco.loc[trep_focco['nome_representante']=='L.S.A - PAULO SERGIO PORTO']
