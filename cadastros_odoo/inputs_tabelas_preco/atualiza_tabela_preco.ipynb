# %% [markdown]
# # Atualização incremental de tabela de preço
#
# Fluxo:
# 1. Carrega dados novos do Focco
# 2. Carrega linhas existentes no Odoo para a mesma tabela
# 3. Compara campo a campo usando `preco_focco_id` como chave
# 4. Exibe diff (o que vai mudar) antes de aplicar
# 5. Aplica: atualiza linhas alteradas, insere novas, sinaliza removidas

# %%
from sqlalchemy import create_engine, text
import xmlrpc.client
import pandas as pd

engine = create_engine(
    "postgresql+psycopg2://consulta:consulta@10.1.57.244:5432/dwfocco"
)

ODOO_URL  = "https://crm.brainess.com.br"
ODOO_DB   = "sohome_18"
ODOO_USER = "tiago@sohome.com"
ODOO_PASS = "admin"

common = xmlrpc.client.ServerProxy(f"{ODOO_URL}/xmlrpc/2/common")
uid    = common.authenticate(ODOO_DB, ODOO_USER, ODOO_PASS, {})
if not uid:
    raise Exception("Falha na autenticacao Odoo")
models = xmlrpc.client.ServerProxy(f"{ODOO_URL}/xmlrpc/2/object")
print(f"Odoo: conectado como uid={uid}")
# Out:
# Odoo: conectado como uid=2

# %%
# =====================================================================
# CONFIG
# =====================================================================
COD_PREVEN = 155  # código da tabela a atualizar

# Campos comparados entre Focco e Odoo.
# Remova campos que não quer rastrear.
CAMPOS_COMPARADOS = [
    "produto",
    "categoria",
    "modulacao",
    "comp_modulo",
    "prof_produto",
    "faixa",
    "tipo_acab",
    "embalagem",
    "formula",
    "resp",
    "preco",
]

print("Config OK")
# Out:
# Config OK

# %% [markdown]
# ## 1. Carrega dados do Focco

# %%
query = f"""
WITH base AS (
    SELECT
        TPRECOSVEN_IT.ID           AS PRECO_FOCCO_ID,
        TITENS.COD_ITEM,
        TPRECOSVEN.COD_PREVEN,
        TPRECOSVEN.DESCRICAO       AS TABELA_DESCRICAO,
        REGEXP_REPLACE(TITENS.DESC_TECNICA, '^MODELO\\s+', '', 'i') AS PRODUTO,
        gci.DESCRICAO              AS DESCRICAO,
        TCARACTERISTICAS.COD_CAR,
        TVARIAVEIS.MNEMONICO,
        TITENS_CAR.SEQ,
        TPRECOSVEN_IT.DES_FORMULA  AS FORMULA,
        TPRECOSVEN_IT.PRECO        AS PRECO
    FROM TPRECOSVEN_IT
    JOIN TPRECOSVEN       ON TPRECOSVEN.ID       = TPRECOSVEN_IT.TPRVEN_ID
    JOIN TITENS_COMERCIAL ON TITENS_COMERCIAL.ID = TPRECOSVEN_IT.ITCM_ID
    JOIN TITENS_EMPR      ON TITENS_EMPR.ID      = TITENS_COMERCIAL.ITEMPR_ID
    JOIN TITENS           ON TITENS.ID           = TITENS_EMPR.ITEM_ID
    LEFT JOIN TGRP_CLAS_ITE gci       ON gci.ID                          = TITENS_COMERCIAL.grp_clas_id
    LEFT JOIN TPRC_REGRAS_COM         ON TPRC_REGRAS_COM.TPRVEN_IT_ID    = TPRECOSVEN_IT.ID
    LEFT JOIN TCARACTERISTICAS        ON TCARACTERISTICAS.ID              = TPRC_REGRAS_COM.TCARAC_ID
    LEFT JOIN TITENS_CAR              ON TITENS_CAR.ITEMPR_ID             = TITENS_EMPR.ID
                                     AND TITENS_CAR.TCARAC_ID             = TPRC_REGRAS_COM.TCARAC_ID
    LEFT JOIN TPRC_REGRAS_VAR_COM     ON TPRC_REGRAS_VAR_COM.REGRA_COM_ID = TPRC_REGRAS_COM.ID
    LEFT JOIN TVARIAVEIS              ON TVARIAVEIS.ID                    = TPRC_REGRAS_VAR_COM.TVAR_ID
    WHERE TPRECOSVEN_IT.SIT = 1
      AND TPRECOSVEN.COD_PREVEN = {COD_PREVEN}
)
SELECT
    PRECO_FOCCO_ID, COD_ITEM, COD_PREVEN, TABELA_DESCRICAO, PRODUTO,
    MAX(DESCRICAO) AS DESCRICAO,
    MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'MODULACAO')       AS MODULACAO,
    MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'COMP_MODULO')     AS COMP_MODULO,
    MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'PROF_PRODUTO')    AS PROF_PRODUTO,
    MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'ALT_MODULO')      AS ALT_MODULO,
    MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'TIPO_ACAB')       AS TIPO_ACAB,
    MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'EMBAL_REFORCADA') AS EMBALAGEM,
    MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'BASE_PE')         AS BASE_PE,
    REPLACE(MAX(MNEMONICO) FILTER (WHERE COD_CAR = 'FX_TEC'), 'FX ', '') AS FAIXA,
    STRING_AGG(
        COD_CAR || ':' || MNEMONICO, '|' ORDER BY SEQ
    ) FILTER (WHERE COD_CAR IS NOT NULL AND MNEMONICO IS NOT NULL) AS RESP,
    FORMULA,
    PRECO
FROM base
GROUP BY PRECO_FOCCO_ID, COD_ITEM, COD_PREVEN, TABELA_DESCRICAO, PRODUTO, FORMULA, PRECO
ORDER BY PRODUTO, MODULACAO, COMP_MODULO, FAIXA;
"""

df_focco = pd.read_sql(text(query), engine)
engine.dispose()

def _norm(v):
    """Normaliza valor para comparação: NaN/None vira string vazia."""
    if v is None or (isinstance(v, float) and pd.isna(v)):
        return ""
    return str(v).strip()

# Monta dict Focco: {preco_focco_id: {campo: valor_normalizado}}
focco = {}
for _, row in df_focco.iterrows():
    fid = int(row["preco_focco_id"])
    focco[fid] = {
        "produto":      _norm(row["produto"]),
        "categoria":    _norm(row["descricao"]),
        "cod_item":     _norm(row["cod_item"]),
        "cod_preven":   int(row["cod_preven"]),
        "tabela_descricao": _norm(row["tabela_descricao"]),
        "modulacao":    _norm(row["modulacao"]),
        "comp_modulo":  _norm(row["comp_modulo"]),
        "prof_produto": _norm(row["prof_produto"]),
        "faixa":        _norm(row["faixa"]),
        "tipo_acab":    _norm(row["tipo_acab"]),
        "embalagem":    _norm(row["embalagem"]),
        "formula":      _norm(row["formula"]),
        "resp":         _norm(row["resp"]),
        "preco":        float(row["preco"]),
    }

print(f"Focco: {len(focco)} linhas para cod_preven={COD_PREVEN}")
# Out:
# Focco: 252059 linhas para cod_preven=155

# %% [markdown]
# ## 2. Carrega linhas existentes no Odoo

# %%
ODOO_FIELDS = [
    "id", "preco_focco_id", "produto", "categoria", "cod_item",
    "cod_preven", "tabela_descricao", "modulacao", "comp_modulo",
    "prof_produto", "faixa", "tipo_acab", "embalagem",
    "formula", "resp", "preco",
]

registros = models.execute_kw(
    ODOO_DB, uid, ODOO_PASS,
    "calculadora.price.line", "search_read",
    [[["cod_preven", "=", COD_PREVEN]]],
    {"fields": ODOO_FIELDS, "limit": 0}
)

# Monta dict Odoo: {preco_focco_id: {campo: valor_normalizado, '_odoo_id': id}}
odoo = {}
for r in registros:
    fid = int(r["preco_focco_id"])
    odoo[fid] = {
        "_odoo_id":     r["id"],
        "produto":      _norm(r["produto"]),
        "categoria":    _norm(r["categoria"]),
        "cod_item":     _norm(r["cod_item"]),
        "cod_preven":   int(r["cod_preven"]) if r["cod_preven"] else 0,
        "tabela_descricao": _norm(r["tabela_descricao"]),
        "modulacao":    _norm(r["modulacao"]),
        "comp_modulo":  _norm(r["comp_modulo"]),
        "prof_produto": _norm(r["prof_produto"]),
        "faixa":        _norm(r["faixa"]),
        "tipo_acab":    _norm(r["tipo_acab"]),
        "embalagem":    _norm(r["embalagem"]),
        "formula":      _norm(r["formula"]),
        "resp":         _norm(r["resp"]),
        "preco":        float(r["preco"]) if r["preco"] else 0.0,
    }

print(f"Odoo  : {len(odoo)} linhas para cod_preven={COD_PREVEN}")
# Out:
# Odoo  : 252088 linhas para cod_preven=155

# %% [markdown]
# ## 3. Diff — o que vai mudar
#
# Compara campo a campo usando `preco_focco_id` como chave estável.
# Nenhuma alteração é feita aqui — só visualização.

# %%
ids_focco = set(focco.keys())
ids_odoo  = set(odoo.keys())

ids_novos    = ids_focco - ids_odoo          # existem no Focco, não no Odoo → INSERT
ids_removidos = ids_odoo - ids_focco         # existem no Odoo, sumiram do Focco → sinalizar
ids_comuns   = ids_focco & ids_odoo          # existem nos dois → comparar

# Linhas a atualizar: campos diferentes
atualizacoes = []   # [{preco_focco_id, odoo_id, diffs: {campo: (de, para)}}]

for fid in ids_comuns:
    f = focco[fid]
    o = odoo[fid]
    diffs = {}
    for campo in CAMPOS_COMPARADOS:
        v_focco = f.get(campo, "")
        v_odoo  = o.get(campo, "")
        # Comparação numérica para preco (evita 4000.0 != 4000)
        if campo == "preco":
            if abs(float(v_focco) - float(v_odoo)) > 0.001:
                diffs[campo] = (v_odoo, v_focco)
        else:
            if str(v_focco) != str(v_odoo):
                diffs[campo] = (v_odoo, v_focco)
    if diffs:
        atualizacoes.append({
            "preco_focco_id": fid,
            "odoo_id":        odoo[fid]["_odoo_id"],
            "produto":        focco[fid]["produto"],
            "diffs":          diffs,
        })

# ── Resumo ──────────────────────────────────────────────────────────────────
SEP = "=" * 68
print(SEP)
print(f"DIFF  cod_preven={COD_PREVEN}")
print(SEP)
print(f"  Novas (INSERT)      : {len(ids_novos)}")
print(f"  Alteradas (UPDATE)  : {len(atualizacoes)}")
print(f"  Removidas do Focco  : {len(ids_removidos)}")
print(f"  Sem alteracao       : {len(ids_comuns) - len(atualizacoes)}")
print()

# Detalha alterações
if atualizacoes:
    print("── ALTERAÇÕES ──")
    for item in atualizacoes[:50]:  # limita exibição a 50
        print(f"  [{item['preco_focco_id']}] {item['produto']}")
        for campo, (de, para) in item["diffs"].items():
            if campo == "preco":
                print(f"    {campo:<15} R${float(de):>10,.2f}  →  R${float(para):>10,.2f}")
            else:
                de_str   = str(de)[:40]   if de   else '(vazio)'
                para_str = str(para)[:40] if para else '(vazio)'
                print(f"    {campo:<15} {de_str!r}  →  {para_str!r}")
    if len(atualizacoes) > 50:
        print(f"  ... e mais {len(atualizacoes) - 50} alterações (não exibidas)")

if ids_removidos:
    print()
    print("── REMOVIDAS DO FOCCO (não serão deletadas automaticamente) ──")
    for fid in list(ids_removidos)[:20]:
        print(f"  [{fid}] {odoo[fid]['produto']}")
    if len(ids_removidos) > 20:
        print(f"  ... e mais {len(ids_removidos) - 20}")
# Out:
# ====================================================================
# DIFF  cod_preven=155
# ====================================================================
#   Novas (INSERT)      : 1
#   Alteradas (UPDATE)  : 252058
#   Removidas do Focco  : 30
#   Sem alteracao       : 0
#
# ── ALTERAÇÕES ──
#   [12058624] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058625] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058627] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058630] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058632] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058634] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058637] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058640] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058641] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058644] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058647] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058649] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058651] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058653] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058656] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058658] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058660] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058663] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058664] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058667] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058670] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058671] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058674] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058677] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058678] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058681] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058683] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058685] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058688] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058690] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058693] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058696] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058697] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058700] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058703] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058704] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058706] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058709] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058712] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058713] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058716] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058719] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058720] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058723] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058726] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058728] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058729] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058733] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058735] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   [12058738] GROOVE
#     categoria       'False'  →  'SOFAS LIVING'
#   ... e mais 252008 alterações (não exibidas)
#
# ── REMOVIDAS DO FOCCO (não serão deletadas automaticamente) ──
#   [12354375] MESA CENTRO PICASSO
#   [12354376] MESA CENTRO PICASSO
#   [12354377] MESA CENTRO PICASSO
#   [12354378] MESA CENTRO PICASSO
#   [12354379] MESA CENTRO PICASSO
#   [12354380] MESA CENTRO PICASSO
#   [12354381] MESA CENTRO PICASSO
#   [12354382] MESA CENTRO PICASSO
#   [12354383] MESA CENTRO PICASSO
#   [12354384] MESA CENTRO PICASSO
#   [12354385] MESA CENTRO PICASSO
#   [12354386] MESA CENTRO PICASSO
#   [12354387] MESA CENTRO PICASSO
#   [12354388] MESA CENTRO PICASSO
#   [12354389] MESA CENTRO PICASSO
#   [12354390] MESA CENTRO PICASSO
#   [12354391] MESA CENTRO PICASSO
#   [12354392] MESA CENTRO PICASSO
#   [12354393] MESA CENTRO PICASSO
#   [12354394] MESA CENTRO PICASSO
#   ... e mais 10

# %% [markdown]
# ## 4. Aplica as mudanças
#
# Rode esta célula **somente depois de revisar o diff acima**.
#
# - Linhas alteradas → `write` apenas nos campos que mudaram
# - Linhas novas → `create`
# - Linhas removidas do Focco → **não são deletadas**, apenas listadas no diff

# %%
RESP_KEYS_COVERED = {
    "MODULACAO", "COMP_MODULO", "PROF_PRODUTO",
    "FX_TEC", "TIPO_ACAB", "EMBAL_REFORCADA",
    "MATERIAL_TAMPO", "MAT_PE_BASE", "FORMATO_MOD", "ALT_MODULO",
}

def resp_extras(resp_str, covered):
    extras = {}
    if not resp_str:
        return extras
    for part in str(resp_str).split("|"):
        if ":" in part:
            k, _, v = part.partition(":")
            k = k.strip()
            if k not in covered:
                extras[k] = v.strip()
    return extras


# ── Busca tabela_id no Odoo ──────────────────────────────────────────────────
tabela_ids = models.execute_kw(
    ODOO_DB, uid, ODOO_PASS,
    "calculadora.price.table", "search",
    [[["cod_preven", "=", COD_PREVEN]]]
)
if not tabela_ids:
    raise Exception(f"Tabela cod_preven={COD_PREVEN} não encontrada no Odoo.")
tabela_id = tabela_ids[0]


# ── UPDATE ───────────────────────────────────────────────────────────────────
upd_ok = upd_err = 0
for item in atualizacoes:
    # Monta vals apenas com os campos que mudaram
    vals = {campo: focco[item["preco_focco_id"]].get(campo)
            for campo in item["diffs"]}
    try:
        models.execute_kw(
            ODOO_DB, uid, ODOO_PASS,
            "calculadora.price.line", "write",
            [[item["odoo_id"]], vals]
        )
        upd_ok += 1
    except Exception as e:
        print(f"  Erro UPDATE [{item['preco_focco_id']}]: {e}")
        upd_err += 1


# ── INSERT ───────────────────────────────────────────────────────────────────
ins_ok = ins_err = 0
BATCH = 100
novos_list = list(ids_novos)
for i in range(0, len(novos_list), BATCH):
    lote_ids = novos_list[i:i+BATCH]
    batch_vals = []
    for fid in lote_ids:
        f = focco[fid]
        extras = resp_extras(f["resp"], RESP_KEYS_COVERED)
        batch_vals.append({
            "price_table_id":  tabela_id,
            "preco_focco_id":  fid,
            "cod_item":        f["cod_item"],
            "cod_preven":      f["cod_preven"],
            "tabela_descricao": f["tabela_descricao"],
            "produto":         f["produto"],
            "categoria":       f["categoria"],
            "modulacao":       f["modulacao"],
            "comp_modulo":     f["comp_modulo"],
            "prof_produto":    f["prof_produto"],
            "faixa":           f["faixa"],
            "tipo_acab":       f["tipo_acab"],
            "embalagem":       f["embalagem"],
            "formula":         f["formula"],
            "resp":            f["resp"],
            "resp_extras":     str(extras) if extras else "",
            "preco":           f["preco"],
        })
    try:
        models.execute_kw(ODOO_DB, uid, ODOO_PASS,
                          "calculadora.price.line", "create", [batch_vals])
        ins_ok += len(batch_vals)
    except Exception as e:
        print(f"  Erro INSERT lote: {e}")
        ins_err += len(batch_vals)


# ── Resultado ────────────────────────────────────────────────────────────────
print(f"UPDATE : {upd_ok} OK | {upd_err} erros")
print(f"INSERT : {ins_ok} OK | {ins_err} erros")
if ids_removidos:
    print(f"REMOVIDAS do Focco: {len(ids_removidos)} linhas — não deletadas, revisar manualmente se necessário")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 44
#      40             "calculadora.price.line", "write",
#      41             [[item["odoo_id"]], vals]
#      42         )
#      43         upd_ok += 1
# ---> 44     except Exception as e:
#      45         print(f"  Erro UPDATE [{item['preco_focco_id']}]: {e}")
#      46         upd_err += 1
#      47
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3568.0_x64__qbz5n2kfra8p0\Lib\xmlrpc\client.py:1096, in _Method.__call__(self, *args)
#    1095 def __call__(self, *args):
# -> 1096     return self.__send(self.__name, args)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3568.0_x64__qbz5n2kfra8p0\Lib\xmlrpc\client.py:1435, in ServerProxy.__request(self, methodname, params)
#    1429 def __request(self, methodname, params):
#    1430     # call a method on the remote server
#    1432     request = dumps(params, methodname, encoding=self.__encoding,
#    1433                     allow_none=self.__allow_none).encode(self.__encoding, 'xmlcharrefreplace')
# -> 1435     response = self.__transport.request(
#    1436         self.__host,
#    1437         self.__handler,
#    1438         request,
#    1439         verbose=self.__verbose
#    1440         )
#    1442     if len(response) == 1:
#    1443         response = response[0]
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3568.0_x64__qbz5n2kfra8p0\Lib\xmlrpc\client.py:1140, in Transport.request(self, host, handler, request_body, verbose)
#    1138 for i in (0, 1):
#    1139     try:
# -> 1140         return self.single_request(host, handler, request_body, verbose)
#    1141     except http.client.RemoteDisconnected:
#    1142         if i:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3568.0_x64__qbz5n2kfra8p0\Lib\xmlrpc\client.py:1153, in Transport.single_request(self, host, handler, request_body, verbose)
#    1151 try:
#    1152     http_conn = self.send_request(host, handler, request_body, verbose)
# -> 1153     resp = http_conn.getresponse()
#    1154     if resp.status == 200:
#    1155         self.verbose = verbose
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3568.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1450, in HTTPConnection.getresponse(self)
#    1448 try:
#    1449     try:
# -> 1450         response.begin()
#    1451     except ConnectionError:
#    1452         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3568.0_x64__qbz5n2kfra8p0\Lib\http\client.py:336, in HTTPResponse.begin(self)
#     334 # read until we get a non-100 response
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#     338         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3568.0_x64__qbz5n2kfra8p0\Lib\http\client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#     299         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3568.0_x64__qbz5n2kfra8p0\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3568.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3568.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
