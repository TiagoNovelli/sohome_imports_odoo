# %%
from sqlalchemy import create_engine
import pandas as pd
import xmlrpc.client


engine = create_engine(
    "postgresql+psycopg2://consulta:consulta@10.1.57.244:5432/dwfocco"
)
host = "10.1.57.244"
database = "dwfocco"
username = "consulta"
password = "consulta"

# %%
query = """
        SELECT rp.id, rp.nome_fan as nome_fan_representante, rp.cnpj, rp.descricao as nome_representante, rp.nome_fan 
        FROM trepresentantes as rp
        """

trep_focco = pd.read_sql(query, engine)

engine.dispose()

# %%
trep_focco
# Out:
#       id             nome_fan_representante          cnpj  \
# 0    561                      L.S.A - PAULO           NaN
# 1    645                     ORI - ORIVALDO  1.437860e+13
# 2    647          SALLES & CAMARGO - DHIEGO  1.458547e+13
# 3    761               MJ MIRANDA - THULHYO  2.619294e+13
# 4   1001                LOREN K. FABRO PUPO  1.536387e+13
# ..   ...                                ...           ...
# 65  1281                            UNICA 2           NaN
# 66  1301  LSA - PAULA FERNANDA SANTOS SOUSA           NaN
# 67  1441                    LSA CORPORATIVO           NaN
# 68  1521                       GRUPO SOHOME           NaN
# 69   648                 GRX REPRESENTAÇÕES  1.716565e+13
#
#                                    nome_representante  \
# 0                          L.S.A - PAULO SERGIO PORTO
# 1             ORIBORGES REPRESENTACOES COMERCIAL LTDA
# 2   SALLES & CAMARGO - REPRESENTACOES COMERCIAIS L...
# ...

# %%
trep_focco.to_excel("representantes_focco2.xlsx", index=False)

# %%
trep_focco = pd.read_excel("representantes_focco.xlsx")

# %%
trep_focco.loc[trep_focco["ativo"]==True]
# Out:
#     Unnamed: 0    id                  nome_fan_representante          cnpj  \
# 1            1   645                          ORI - ORIVALDO  1.437860e+13
# 6            6  1221                             ORI - JULIA           NaN
# 11          11  1461                 A Z REPRESENTACOES LTDA  5.570747e+13
# 12          12  1481  LSA-  LÍVIA MORELLI ANDRADE DOS SANTOS           NaN
# 19          19   861                           LSA - LUCIANO  2.933139e+13
# 21          21   921                        SACCARO - DIRETO           NaN
# 24          24  1241                GABRIELA SIQUEIRA VIEIRA           NaN
# 26          26  1565                           LSA - LITORAL           NaN
# 38          38   670              A.J.P. REPRESENTACOES LTDA  9.131207e+12
# 39          39   672                          JARDIM - VITOR  1.702277e+13
# 41          41   741                         BRETON - DIRETO           NaN
# ...

# %%
#trep_focco.loc[trep_focco['nome_representante']=='L.S.A - PAULO SERGIO PORTO']
