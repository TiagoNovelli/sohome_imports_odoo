# %%
from sqlalchemy import create_engine
import pandas as pd
import xmlrpc.client


engine = create_engine(
    "postgresql+psycopg2://consulta:consulta@10.1.57.244:5432/dwfocco"
)
host = "10.1.57.244"
database = "dwfocco"
username = "consulta"
password = "consulta"

# %%
query = """
        SELECT rp.id, rp.nome_fan as nome_fan_representante, rp.cnpj, rp.descricao as nome_representante, rp.nome_fan 
        FROM trepresentantes as rp
        """

df = pd.read_sql(query, engine)

engine.dispose()

# %%
df
# Out:
#       id             nome_fan_representante          cnpj  \
# 0    561                      L.S.A - PAULO           NaN
# 1    645                     ORI - ORIVALDO  1.437860e+13
# 2    647          SALLES & CAMARGO - DHIEGO  1.458547e+13
# 3    761               MJ MIRANDA - THULHYO  2.619294e+13
# 4   1001                LOREN K. FABRO PUPO  1.536387e+13
# ..   ...                                ...           ...
# 65  1281                            UNICA 2           NaN
# 66  1301  LSA - PAULA FERNANDA SANTOS SOUSA           NaN
# 67  1441                    LSA CORPORATIVO           NaN
# 68  1521                       GRUPO SOHOME           NaN
# 69   648                 GRX REPRESENTAÇÕES  1.716565e+13
#
#                                    nome_representante  \
# 0                          L.S.A - PAULO SERGIO PORTO
# 1             ORIBORGES REPRESENTACOES COMERCIAL LTDA
# 2   SALLES & CAMARGO - REPRESENTACOES COMERCIAIS L...
# 3             MJ MIRANDA CARREIRO REPRESENTACOES LTDA
# 4                                 LOREN K. FABRO PUPO
# ..                                                ...
# 65          DANIELA DE BARROS AMORIM REPRESENTAÇÕES 2
# 66                  LSA - PAULA FERNANDA SANTOS SOUSA
# 67                                    LSA CORPORATIVO
# 68                                       GRUPO SOHOME
# 69                 GRX REPRESENTACOES COMERCIAIS LTDA
#
#                              nome_fan
# 0                       L.S.A - PAULO
# 1                      ORI - ORIVALDO
# 2           SALLES & CAMARGO - DHIEGO
# 3                MJ MIRANDA - THULHYO
# 4                 LOREN K. FABRO PUPO
# ..                                ...
# 65                            UNICA 2
# 66  LSA - PAULA FERNANDA SANTOS SOUSA
# 67                    LSA CORPORATIVO
# 68                       GRUPO SOHOME
# 69                 GRX REPRESENTAÇÕES
#
# [70 rows x 5 columns]

# %%
def tratar_cnpj(valor):
    if pd.isna(valor):
        return None
    
    # remove .0 e notação científica convertendo para inteiro antes
    cnpj = str(int(float(valor)))
    
    # completa zeros à esquerda até 14 dígitos
    return cnpj.zfill(14)

df["cnpj"] = df["cnpj"].apply(tratar_cnpj)

# %%
df.dropna(subset=["cnpj"])
# Out:
#       id                             nome_fan_representante            cnpj  \
# 1    645                                     ORI - ORIVALDO  14378602000191
# 2    647                          SALLES & CAMARGO - DHIEGO  14585474000157
# 3    761                               MJ MIRANDA - THULHYO  26192937000108
# 4   1001                                LOREN K. FABRO PUPO  15363869000178
# 11  1461                            A Z REPRESENTACOES LTDA  55707471000126
# 13  1561                       CAROLINE REIS REPRESENTACOES  45403167000131
# 14   701                            SULAMERICANA - ANDERSON  18887524000101
# 19   861                                      LSA - LUCIANO  29331390000164
# 22   941       BONANZA SV CONSULTORIA E ADMNISTRACAO EIRELI  32077671000147
# 23   981  MERCATTO DECORACAO DE INTERIORES, DESENHOS E P...  20666958000123
# 28   646                                 M.A.F. - MERCANTIL  10214539000105
# 29   661                           CASTRO BIANCHI - RICARDO  09333569000143
# 30   662                                      SATIN - LUCAS  31783842000190
# 31   663                                LORCA - BRUNO LORCA  11632235000112
# 32   664                               BOLICASTRO - LUCIENI  10895937000126
# 33   665                                    SOLAR - LETÍCIA  24961180000136
# 34   666                                 DEMARIO - FERNANDO  54671953000100
# 35   667                                    SANTOS - ROBSON  09003580000145
# 36   668                                  EVEREST - RODOLFO  20793842000155
# 37   669                                   SERRA - FABRIZIO  30235961000146
# 38   670                         A.J.P. REPRESENTACOES LTDA  09131207000170
# 39   672                                     JARDIM - VITOR  17022772000127
# 40   681                                     DECOR - ELIANE  34813368000190
# 42   841                        EXCLUSIVA CENTURY - MARINGÁ  08761211000159
# 43   961             RSSTB REPRESENTACOES E COMERCIO EIRELI  36315089000122
# 46  1261              NATAN SERVICOS DE REPRESENTACOES LTDA  41884976000151
# 50  1381                           DESIGN TRADE VENDAS LTDA  58368012000153
# 53   604                                    SOHOME - DIRETO  02749435000169
# 54   622                    L.S.A. REPRESENTAÇÕES - LUCIANO  04030850000193
# 56   643                                      EN7 - EDUARDO  14526604000180
# 57   644                                    ÚNICA - DANIELA  14045921000185
# 58   649                                  J C - JÚLIO CESAR  81760845000187
# 59   650                                   WSA - WASHINGTON  05118949000104
# 60   651                                      LIGHT - LAINE  02547084000103
# 61   673                                LIMA E LIMA - NEIDE  11464242000152
# 62   674                                   OESTESUL - PABLO  02254360000145
# 63   901                                          TERCEIROS  00000000000000
# 69   648                                 GRX REPRESENTAÇÕES  17165651000134
#
#                                    nome_representante  \
# 1             ORIBORGES REPRESENTACOES COMERCIAL LTDA
# 2   SALLES & CAMARGO - REPRESENTACOES COMERCIAIS L...
# 3             MJ MIRANDA CARREIRO REPRESENTACOES LTDA
# 4                                 LOREN K. FABRO PUPO
# 11                            A Z REPRESENTACOES LTDA
# 13                            CRS REPRESENTACOES LTDA
# 14                             ANDERSON PIRES BARBOZA
# 19          LLA COMERCIO E SERVICOS DE TAPECARIA LTDA
# 22       BONANZA SV CONSULTORIA E ADMNISTRACAO EIRELI
# 23  MERCATTO DECORACAO DE INTERIORES, DESENHOS E P...
# 28        M.FURLANETTO REPRESENTACOES COMERCIAIS LTDA
# 29  CASTRO BIANCHI CONSULTORIA E REPRESENTACAO COM...
# 30                                   SATIN & CIA LTDA
# 31                                BRUNO MARTINS LORCA
# 32          BOLICASTRO REPRESENTACOES COMERCIAIS LTDA
# 33       GOMES E JATENE COMERCIO E REPRESENTACAO LTDA
# 34                     DEMARIO REPRESENTACOES SC LTDA
# 35  SANTOS DISTRIBUIDORA E REPRESENTACAO DE MOVEIS...
# 36             EVEREST REPRESENTACOES COMERCIAIS LTDA
# 37                             FS REPRESENTACOES LTDA
# 38                         A.J.P. REPRESENTACOES LTDA
# 39                     VITOR C. JARDIM REPRESENTACOES
# 40                                 ELIANE COSTA SILVA
# 42            LUIZ DAMASCENO MOVEIS E DECORACOES LTDA
# 43             RSSTB REPRESENTACOES E COMERCIO EIRELI
# 46              NATAN SERVICOS DE REPRESENTACOES LTDA
# 50                           DESIGN TRADE VENDAS LTDA
# 53                                  GRUPO SOHOME LTDA
# 54  L.S.A. REPRESENTACOES E SERVICOS DE TAPECARIAS...
# 56  EN7 REPRESENTACOES. CONSULTORIA TREINAMENTO E ...
# 57            DANIELA DE BARROS AMORIM REPRESENTAÇÕES
# 58  J C GESTAO E ADMINISTRACAO DE PROPRIEDADE S/S ...
# 59             WASHINGTON AZEVEDO REPRESENTACOES LTDA
# 60                     LIGHT REPRESENTACOES LTDA - ME
# 61                    LIMA E LIMA REPRESENTACOES LTDA
# 62          PABLO REPRESENTACOES OESTE SUL BAHIA LTDA
# 63                                          TERCEIROS
# 69                 GRX REPRESENTACOES COMERCIAIS LTDA
#
#                                              nome_fan
# 1                                      ORI - ORIVALDO
# 2                           SALLES & CAMARGO - DHIEGO
# 3                                MJ MIRANDA - THULHYO
# 4                                 LOREN K. FABRO PUPO
# 11                            A Z REPRESENTACOES LTDA
# 13                       CAROLINE REIS REPRESENTACOES
# 14                            SULAMERICANA - ANDERSON
# 19                                      LSA - LUCIANO
# 22       BONANZA SV CONSULTORIA E ADMNISTRACAO EIRELI
# 23  MERCATTO DECORACAO DE INTERIORES, DESENHOS E P...
# 28                                 M.A.F. - MERCANTIL
# 29                           CASTRO BIANCHI - RICARDO
# 30                                      SATIN - LUCAS
# 31                                LORCA - BRUNO LORCA
# 32                               BOLICASTRO - LUCIENI
# 33                                    SOLAR - LETÍCIA
# 34                                 DEMARIO - FERNANDO
# 35                                    SANTOS - ROBSON
# 36                                  EVEREST - RODOLFO
# 37                                   SERRA - FABRIZIO
# 38                         A.J.P. REPRESENTACOES LTDA
# 39                                     JARDIM - VITOR
# 40                                     DECOR - ELIANE
# 42                        EXCLUSIVA CENTURY - MARINGÁ
# 43             RSSTB REPRESENTACOES E COMERCIO EIRELI
# 46              NATAN SERVICOS DE REPRESENTACOES LTDA
# 50                           DESIGN TRADE VENDAS LTDA
# 53                                    SOHOME - DIRETO
# 54                    L.S.A. REPRESENTAÇÕES - LUCIANO
# 56                                      EN7 - EDUARDO
# 57                                    ÚNICA - DANIELA
# 58                                  J C - JÚLIO CESAR
# 59                                   WSA - WASHINGTON
# 60                                      LIGHT - LAINE
# 61                                LIMA E LIMA - NEIDE
# 62                                   OESTESUL - PABLO
# 63                                          TERCEIROS
# 69                                 GRX REPRESENTAÇÕES

# %%
# =====================================
# CONEXÃO ODOO
# =====================================

url = "https://crm.brainess.com.br"
db = "sohome_18"
username = "tiago@sohome.com"
password = "admin"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})

if not uid:
    raise Exception("Falha na autenticação")

models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")

# %%
# =====================================
# CONFIGURAÇÕES DO IMPORT
# =====================================

module_name = "import_representantes"
tag_name = "REPRESENTANTES"

# =====================================
# GARANTE TAG REPRESENTANTES
# =====================================

tag_ids = models.execute_kw(
    db, uid, password,
    "res.partner.category",
    "search",
    [[["name", "=", tag_name]]],
    {"limit": 1}
)

if tag_ids:
    tag_id = tag_ids[0]
else:
    tag_id = models.execute_kw(
        db, uid, password,
        "res.partner.category",
        "create",
        [{"name": tag_name}]
    )

# =====================================
# FUNÇÃO CNPJ
# =====================================

def tratar_cnpj(valor):
    if pd.isna(valor):
        return False

    cnpj = str(valor).strip()
    cnpj = (
        cnpj
        .replace(".", "")
        .replace("/", "")
        .replace("-", "")
        .replace(" ", "")
    )

    if cnpj.endswith(".0"):
        cnpj = cnpj[:-2]

    return cnpj.zfill(14)

# %%
df_empresas = df.copy()

# %%
# =====================================
# LOOP CADASTRO / ATUALIZAÇÃO
# =====================================

criados = 0
atualizados = 0
ignorados = 0

for _, row in df_empresas.iterrows():

    id_origem = row.get("id")

    if pd.isna(id_origem):
        ignorados += 1
        continue

    id_origem = str(int(id_origem))

    external_name = f"representante_{id_origem}"

    nome = row.get("nome_representante")
    nome_fantasia = row.get("nome_fan")
    cnpj = tratar_cnpj(row.get("cnpj"))

    if not nome:
        ignorados += 1
        continue

    vals = {
        "name": nome,
        "is_company": True,
        "company_type": "company",
        "category_id": [(4, tag_id)],
    }

    if nome_fantasia:
        vals["commercial_company_name"] = nome_fantasia

    if cnpj:
        vals["vat"] = cnpj

    # =====================================
    # BUSCA PELO EXTERNAL ID
    # =====================================

    external_ids = models.execute_kw(
        db, uid, password,
        "ir.model.data",
        "search_read",
        [[
            ["module", "=", module_name],
            ["name", "=", external_name],
            ["model", "=", "res.partner"],
        ]],
        {
            "fields": ["res_id"],
            "limit": 1,
        }
    )

    if external_ids:
        partner_id = external_ids[0]["res_id"]

        models.execute_kw(
            db, uid, password,
            "res.partner",
            "write",
            [[partner_id], vals]
        )

        atualizados += 1
        print(f"ATUALIZADO: {module_name}.{external_name} | {nome}")

    else:
        partner_id = models.execute_kw(
            db, uid, password,
            "res.partner",
            "create",
            [vals]
        )

        models.execute_kw(
            db, uid, password,
            "ir.model.data",
            "create",
            [{
                "module": module_name,
                "name": external_name,
                "model": "res.partner",
                "res_id": partner_id,
                "noupdate": True,
            }]
        )

        criados += 1
        print(f"CRIADO: {module_name}.{external_name} | {nome}")

print("\nFINALIZADO")
print(f"Criados: {criados}")
print(f"Atualizados: {atualizados}")
print(f"Ignorados: {ignorados}")
# Out:
# CRIADO: import_representantes.representante_561 | L.S.A - PAULO SERGIO PORTO
# CRIADO: import_representantes.representante_645 | ORIBORGES REPRESENTACOES COMERCIAL LTDA
# CRIADO: import_representantes.representante_647 | SALLES & CAMARGO - REPRESENTACOES COMERCIAIS LTDA - ME
# CRIADO: import_representantes.representante_761 | MJ MIRANDA CARREIRO REPRESENTACOES LTDA
# CRIADO: import_representantes.representante_1001 | LOREN K. FABRO PUPO
# CRIADO: import_representantes.representante_1061 | REFORMA
# CRIADO: import_representantes.representante_1221 | ORI - JULIA
# CRIADO: import_representantes.representante_1324 | LUCAS CARDOSO GUISELINI
# CRIADO: import_representantes.representante_1341 | INDICAÇÃO - GABRIELA
# CRIADO: import_representantes.representante_1342 | INDICAÇÃO - CARLOS
# CRIADO: import_representantes.representante_1361 | IAGO GABRIEL BRAGA GRIMALDI
# CRIADO: import_representantes.representante_1461 | A Z REPRESENTACOES LTDA
# CRIADO: import_representantes.representante_1481 | LSA-  LÍVIA MORELLI ANDRADE DOS SANTOS
# CRIADO: import_representantes.representante_1561 | CRS REPRESENTACOES LTDA
# CRIADO: import_representantes.representante_701 | ANDERSON PIRES BARBOZA
# CRIADO: import_representantes.representante_702 | MAIARA VANESSA QUAGIO
# CRIADO: import_representantes.representante_721 | LSA - FERNANDO CASTRO BATISTA
# CRIADO: import_representantes.representante_781 | EXPORTACAO - DIRETO
# CRIADO: import_representantes.representante_821 | CARLOS ALBERTO TORRES PEREIRA JUNIOR
# CRIADO: import_representantes.representante_861 | LLA COMERCIO E SERVICOS DE TAPECARIA LTDA
# CRIADO: import_representantes.representante_881 | ASSISTENCIA TECNICA
# CRIADO: import_representantes.representante_921 | SACCARO - DIRETO
# CRIADO: import_representantes.representante_941 | BONANZA SV CONSULTORIA E ADMNISTRACAO EIRELI
# CRIADO: import_representantes.representante_981 | MERCATTO DECORACAO DE INTERIORES, DESENHOS E PROMOCOES TECNICAS LTDA
# CRIADO: import_representantes.representante_1241 | GABRIELA SIQUEIRA VIEIRA
# CRIADO: import_representantes.representante_1421 | AMANDA DA SILVA MOREIRA
# CRIADO: import_representantes.representante_1565 | LSA - LITORAL
# CRIADO: import_representantes.representante_642 | L.S.A. - JERONIMO LUCIO FERNANDES
# CRIADO: import_representantes.representante_646 | M.FURLANETTO REPRESENTACOES COMERCIAIS LTDA
# CRIADO: import_representantes.representante_661 | CASTRO BIANCHI CONSULTORIA E REPRESENTACAO COMERCIAL LTDA
# CRIADO: import_representantes.representante_662 | SATIN & CIA LTDA
# CRIADO: import_representantes.representante_663 | BRUNO MARTINS LORCA
# CRIADO: import_representantes.representante_664 | BOLICASTRO REPRESENTACOES COMERCIAIS LTDA
# CRIADO: import_representantes.representante_665 | GOMES E JATENE COMERCIO E REPRESENTACAO LTDA
# CRIADO: import_representantes.representante_666 | DEMARIO REPRESENTACOES SC LTDA
# CRIADO: import_representantes.representante_667 | SANTOS DISTRIBUIDORA E REPRESENTACAO DE MOVEIS LTDA
# CRIADO: import_representantes.representante_668 | EVEREST REPRESENTACOES COMERCIAIS LTDA
# CRIADO: import_representantes.representante_669 | FS REPRESENTACOES LTDA
# CRIADO: import_representantes.representante_670 | A.J.P. REPRESENTACOES LTDA
# CRIADO: import_representantes.representante_672 | VITOR C. JARDIM REPRESENTACOES
# CRIADO: import_representantes.representante_681 | ELIANE COSTA SILVA
# CRIADO: import_representantes.representante_741 | BRETON - DIRETO
# CRIADO: import_representantes.representante_841 | LUIZ DAMASCENO MOVEIS E DECORACOES LTDA
# CRIADO: import_representantes.representante_961 | RSSTB REPRESENTACOES E COMERCIO EIRELI
# CRIADO: import_representantes.representante_1121 | LSA - MARCIA MORELLI
# CRIADO: import_representantes.representante_1141 | CST - CUSTOMIZACAO01
# CRIADO: import_representantes.representante_1261 | NATAN SERVICOS DE REPRESENTACOES LTDA
# CRIADO: import_representantes.representante_1321 | FERNANDA BENTO CUNHA
# CRIADO: import_representantes.representante_1322 | MANUELA QUAGIO CANOVA
# CRIADO: import_representantes.representante_1325 | RODOLPHO ALVES DOS SANTOS
# CRIADO: import_representantes.representante_1381 | DESIGN TRADE VENDAS LTDA
# CRIADO: import_representantes.representante_1501 | ERICA SILVELENE FALEIRO
# CRIADO: import_representantes.representante_1541 | LSA- LITORAL
# CRIADO: import_representantes.representante_604 | GRUPO SOHOME LTDA
# CRIADO: import_representantes.representante_622 | L.S.A. REPRESENTACOES E SERVICOS DE TAPECARIAS LTDA
# CRIADO: import_representantes.representante_641 | LSA - LUCIANO MORETTI DE ABREU
# CRIADO: import_representantes.representante_643 | EN7 REPRESENTACOES. CONSULTORIA TREINAMENTO E COMERCIO LTDA
# CRIADO: import_representantes.representante_644 | DANIELA DE BARROS AMORIM REPRESENTAÇÕES
# CRIADO: import_representantes.representante_649 | J C GESTAO E ADMINISTRACAO DE PROPRIEDADE S/S LTDA
# CRIADO: import_representantes.representante_650 | WASHINGTON AZEVEDO REPRESENTACOES LTDA
# CRIADO: import_representantes.representante_651 | LIGHT REPRESENTACOES LTDA - ME
# CRIADO: import_representantes.representante_673 | LIMA E LIMA REPRESENTACOES LTDA
# CRIADO: import_representantes.representante_674 | PABLO REPRESENTACOES OESTE SUL BAHIA LTDA
# CRIADO: import_representantes.representante_901 | TERCEIROS
# CRIADO: import_representantes.representante_1041 | LSA - JULIANA CECCONI
# CRIADO: import_representantes.representante_1281 | DANIELA DE BARROS AMORIM REPRESENTAÇÕES 2
# CRIADO: import_representantes.representante_1301 | LSA - PAULA FERNANDA SANTOS SOUSA
# CRIADO: import_representantes.representante_1441 | LSA CORPORATIVO
# CRIADO: import_representantes.representante_1521 | GRUPO SOHOME
# CRIADO: import_representantes.representante_648 | GRX REPRESENTACOES COMERCIAIS LTDA
#
# FINALIZADO
# Criados: 70
# Atualizados: 0
# Ignorados: 0

# %%
import json

usuarios_para_criar = []

representantes = models.execute_kw(
    db, uid, password,
    "ir.model.data",
    "search_read",
    [[
        ["module", "=", module_name],
        ["model", "=", "res.partner"],
        ["name", "like", "representante_"],
    ]],
    {
        "fields": ["name", "res_id"],
    }
)

for rep in representantes:

    partner_id = rep["res_id"]

    partner = models.execute_kw(
        db, uid, password,
        "res.partner",
        "read",
        [[partner_id]],
        {"fields": ["name"]}
    )[0]

    user_ids = models.execute_kw(
        db, uid, password,
        "res.users",
        "search",
        [[["partner_id", "=", partner_id]]],
        {"limit": 1}
    )

    if not user_ids:
        usuarios_para_criar.append({
            "external_id": rep["name"],
            "partner_id": partner_id,
            "nome": partner["name"],
            "login": ""
        })

with open("representantes_usuarios.json", "w", encoding="utf-8") as f:
    json.dump(usuarios_para_criar, f, ensure_ascii=False, indent=4)

print(f"JSON gerado com {len(usuarios_para_criar)} representantes sem usuário.")
# Out:
# JSON gerado com 70 representantes sem usuário.

# %%
import json

with open("representantes_usuarios.json", "r", encoding="utf-8") as f:
    usuarios = json.load(f)

criados = 0
ignorados = 0

for usuario in usuarios:

    login = usuario.get("login")
    partner_id = usuario.get("partner_id")
    nome = usuario.get("nome")

    if not login:
        ignorados += 1
        print(f"IGNORADO sem login: {nome}")
        continue

    user_existente = models.execute_kw(
        db, uid, password,
        "res.users",
        "search",
        [[["login", "=", login]]],
        {"limit": 1}
    )

    if user_existente:
        ignorados += 1
        print(f"IGNORADO login já existe: {login}")
        continue

    user_id = models.execute_kw(
        db, uid, password,
        "res.users",
        "create",
        [{
            "name": nome,
            "login": login,
            "partner_id": partner_id,
            "groups_id": [(6, 0, [])],
        }]
    )

    criados += 1
    print(f"USUÁRIO CRIADO: {nome} | {login}")

print("\nFINALIZADO")
print(f"Usuários criados: {criados}")
print(f"Ignorados: {ignorados}")
# Out:
# IGNORADO sem login: LOREN K. FABRO PUPO
# USUÁRIO CRIADO: LSA - JULIANA CECCONI | juliana.lsa@sohome.com
# IGNORADO sem login: REFORMA
# USUÁRIO CRIADO: LSA - MARCIA MORELLI | lsa.marcia@sohome.com
# IGNORADO sem login: CST - CUSTOMIZACAO01
# USUÁRIO CRIADO: ORI - JULIA | ori.julia@sohome.com
# USUÁRIO CRIADO: GABRIELA SIQUEIRA VIEIRA | gabriela.siqueira@sohome.com
# USUÁRIO CRIADO: NATAN SERVICOS DE REPRESENTACOES LTDA | natan@sohome.com
# USUÁRIO CRIADO: DANIELA DE BARROS AMORIM REPRESENTAÇÕES 2 | daniela.amorin2@sohome.com
# IGNORADO sem login: LSA - PAULA FERNANDA SANTOS SOUSA
# IGNORADO sem login: FERNANDA BENTO CUNHA
# IGNORADO sem login: MANUELA QUAGIO CANOVA
# IGNORADO sem login: LUCAS CARDOSO GUISELINI
# USUÁRIO CRIADO: RODOLPHO ALVES DOS SANTOS | rodolpho@sohome.com
# IGNORADO sem login: INDICAÇÃO - GABRIELA
# IGNORADO sem login: INDICAÇÃO - CARLOS
# IGNORADO sem login: IAGO GABRIEL BRAGA GRIMALDI
# IGNORADO sem login: DESIGN TRADE VENDAS LTDA
# USUÁRIO CRIADO: AMANDA DA SILVA MOREIRA | amanda.moreira@sohome.com
# IGNORADO sem login: LSA CORPORATIVO
# USUÁRIO CRIADO: A Z REPRESENTACOES LTDA | az@sohome.com
# USUÁRIO CRIADO: LSA-  LÍVIA MORELLI ANDRADE DOS SANTOS | lsa.livia@sohome.com
# IGNORADO sem login: ERICA SILVELENE FALEIRO
# IGNORADO sem login: GRUPO SOHOME
# IGNORADO sem login: LSA- LITORAL
# USUÁRIO CRIADO: CRS REPRESENTACOES LTDA | crs@sohome.com
# USUÁRIO CRIADO: LSA - LITORAL | lsa.litoral@sohome.com
# IGNORADO sem login: L.S.A - PAULO SERGIO PORTO
# IGNORADO sem login: GRUPO SOHOME LTDA
# USUÁRIO CRIADO: L.S.A. REPRESENTACOES E SERVICOS DE TAPECARIAS LTDA | lsa@sohome.com
# USUÁRIO CRIADO: LSA - LUCIANO MORETTI DE ABREU | lsa.luciano@sohome.com
# IGNORADO sem login: L.S.A. - JERONIMO LUCIO FERNANDES
# USUÁRIO CRIADO: EN7 REPRESENTACOES. CONSULTORIA TREINAMENTO E COMERCIO LTDA | en7@sohome.com
# USUÁRIO CRIADO: DANIELA DE BARROS AMORIM REPRESENTAÇÕES | daniela.amorin@sohome.com
# USUÁRIO CRIADO: ORIBORGES REPRESENTACOES COMERCIAL LTDA | oriborges@sohome.com
# USUÁRIO CRIADO: M.FURLANETTO REPRESENTACOES COMERCIAIS LTDA | m.furlanetto@sohome.com
# USUÁRIO CRIADO: SALLES & CAMARGO - REPRESENTACOES COMERCIAIS LTDA - ME | salles@sohome.com
# USUÁRIO CRIADO: GRX REPRESENTACOES COMERCIAIS LTDA | grx@sohome.com
# USUÁRIO CRIADO: J C GESTAO E ADMINISTRACAO DE PROPRIEDADE S/S LTDA | jc.gestao@sohome.com
# USUÁRIO CRIADO: WASHINGTON AZEVEDO REPRESENTACOES LTDA | washington.azevedo@sohome.com
# IGNORADO sem login: LIGHT REPRESENTACOES LTDA - ME
# IGNORADO sem login: CASTRO BIANCHI CONSULTORIA E REPRESENTACAO COMERCIAL LTDA
# IGNORADO sem login: SATIN & CIA LTDA
# IGNORADO sem login: BRUNO MARTINS LORCA
# IGNORADO sem login: BOLICASTRO REPRESENTACOES COMERCIAIS LTDA
# USUÁRIO CRIADO: GOMES E JATENE COMERCIO E REPRESENTACAO LTDA | gomes.jatene@sohome.com
# IGNORADO sem login: DEMARIO REPRESENTACOES SC LTDA
# IGNORADO sem login: SANTOS DISTRIBUIDORA E REPRESENTACAO DE MOVEIS LTDA
# IGNORADO sem login: EVEREST REPRESENTACOES COMERCIAIS LTDA
# USUÁRIO CRIADO: FS REPRESENTACOES LTDA | fs@sohome.com
# USUÁRIO CRIADO: A.J.P. REPRESENTACOES LTDA | ajp@sohome.com
# USUÁRIO CRIADO: VITOR C. JARDIM REPRESENTACOES | vitor.jardim@sohome.com
# USUÁRIO CRIADO: LIMA E LIMA REPRESENTACOES LTDA | lima@sohome.com
# USUÁRIO CRIADO: PABLO REPRESENTACOES OESTE SUL BAHIA LTDA | pablo@sohome.com
# IGNORADO sem login: ELIANE COSTA SILVA
# IGNORADO sem login: ANDERSON PIRES BARBOZA
# IGNORADO sem login: MAIARA VANESSA QUAGIO
# IGNORADO sem login: LSA - FERNANDO CASTRO BATISTA
# IGNORADO sem login: BRETON - DIRETO
# IGNORADO sem login: MJ MIRANDA CARREIRO REPRESENTACOES LTDA
# IGNORADO sem login: EXPORTACAO - DIRETO
# USUÁRIO CRIADO: CARLOS ALBERTO TORRES PEREIRA JUNIOR | carlos.alberto@sohome.com
# USUÁRIO CRIADO: LUIZ DAMASCENO MOVEIS E DECORACOES LTDA | luiz.damasceno@sohome.com
# USUÁRIO CRIADO: LLA COMERCIO E SERVICOS DE TAPECARIA LTDA | lla@sohome.com
# IGNORADO sem login: ASSISTENCIA TECNICA
# IGNORADO sem login: TERCEIROS
# USUÁRIO CRIADO: SACCARO - DIRETO | sccaro@sohome.com
# USUÁRIO CRIADO: BONANZA SV CONSULTORIA E ADMNISTRACAO EIRELI | bonanza@sohome.com
# USUÁRIO CRIADO: RSSTB REPRESENTACOES E COMERCIO EIRELI | rsstb@sohome.com
# USUÁRIO CRIADO: MERCATTO DECORACAO DE INTERIORES, DESENHOS E PROMOCOES TECNICAS LTDA | mercato@sohome.com
#
# FINALIZADO
# Usuários criados: 35
# Ignorados: 35
